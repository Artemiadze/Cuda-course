# %%
# !ls /usr/local/
# Out:
# bin    cuda	cuda-12.5	  etc	 include  libexec     man  sbin   src
# colab  cuda-12	dist_metrics.pxd  games  lib	  LICENSE.md  opt  share

# %%
# !which nvcc
# Out:
# /usr/local/cuda/bin/nvcc

# %%
# !nvidia-smi
# Out:
# Tue Jul  8 09:13:13 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# %%writefile 01_idxing.cu
# #include <stdio.h>
#
# __global__ void whoami(void) {
#     int block_id =
#         blockIdx.x +    // apartment number on this floor (points across)
#         blockIdx.y * gridDim.x +    // floor number in this building (rows high)
#         blockIdx.z * gridDim.x * gridDim.y;   // building number in this city (panes deep)
#
#     int block_offset =
#         block_id * // times our apartment number
#         blockDim.x * blockDim.y * blockDim.z; // total threads per block (people per apartment)
#
#     int thread_offset =
#         threadIdx.x +
#         threadIdx.y * blockDim.x +
#         threadIdx.z * blockDim.x * blockDim.y;
#
#     int id = block_offset + thread_offset; // global person id in the entire apartment complex
#
#     printf("%04d | Block(%d %d %d) = %3d | Thread(%d %d %d) = %3d\n",
#         id,
#         blockIdx.x, blockIdx.y, blockIdx.z, block_id,
#         threadIdx.x, threadIdx.y, threadIdx.z, thread_offset);
#     // printf("blockIdx.x: %d, blockIdx.y: %d, blockIdx.z: %d, threadIdx.x: %d, threadIdx.y: %d, threadIdx.z: %d\n", blockIdx.x, blockIdx.y, blockIdx.z, threadIdx.x, threadIdx.y, threadIdx.z);
# }
#
# int main(int argc, char **argv) {
#     const int b_x = 2, b_y = 3, b_z = 4;
#     const int t_x = 4, t_y = 4, t_z = 4; // the max warp size is 32, so
#     // we will get 2 warp of 32 threads per block
#
#     int blocks_per_grid = b_x * b_y * b_z;
#     int threads_per_block = t_x * t_y * t_z;
#
#     printf("%d blocks/grid\n", blocks_per_grid);
#     printf("%d threads/block\n", threads_per_block);
#     printf("%d total threads\n", blocks_per_grid * threads_per_block);
#
#     dim3 blocksPerGrid(b_x, b_y, b_z); // 3d cube of shape 2*3*4 = 24
#     dim3 threadsPerBlock(t_x, t_y, t_z); // 3d cube of shape 4*4*4 = 64
#
#     whoami<<<blocksPerGrid, threadsPerBlock>>>();
#     cudaDeviceSynchronize();
# }
# Out:
# Writing 01_idxing.cu

# %%
# !apt update
# !apt install -y cuda-toolkit-11-8
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,752 kB]
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,262 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,092 kB]
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,078 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,410 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,566 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [4,933 kB]
# Fetched 26.5 MB in 3s (9,999 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 51 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   cuda-cccl-11-8 cuda-command-line-tools-11-8 cuda-compiler-11-8
#   cuda-cudart-11-8 cuda-cudart-dev-11-8 cuda-cuobjdump-11-8 cuda-cupti-11-8
#   cuda-cupti-dev-11-8 cuda-cuxxfilt-11-8 cuda-documentation-11-8
#   cuda-driver-dev-11-8 cuda-gdb-11-8 cuda-libraries-11-8
#   cuda-libraries-dev-11-8 cuda-memcheck-11-8 cuda-nsight-11-8
#   cuda-nsight-compute-11-8 cuda-nsight-systems-11-8 cuda-nvcc-11-8
#   cuda-nvdisasm-11-8 cuda-nvml-dev-11-8 cuda-nvprof-11-8 cuda-nvprune-11-8
#   cuda-nvrtc-11-8 cuda-nvrtc-dev-11-8 cuda-nvtx-11-8 cuda-nvvp-11-8
#   cuda-profiler-api-11-8 cuda-sanitizer-11-8 cuda-toolkit-11-8-config-common
#   cuda-toolkit-11-config-common cuda-tools-11-8 cuda-visual-tools-11-8
#   default-jre default-jre-headless fonts-dejavu-core fonts-dejavu-extra
#   gds-tools-11-8 libatk-wrapper-java libatk-wrapper-java-jni libcublas-11-8
#   libcublas-dev-11-8 libcufft-11-8 libcufft-dev-11-8 libcufile-11-8
#   libcufile-dev-11-8 libcurand-11-8 libcurand-dev-11-8 libcusolver-11-8
#   libcusolver-dev-11-8 libcusparse-11-8 libcusparse-dev-11-8 libnpp-11-8
#   libnpp-dev-11-8 libnvjpeg-11-8 libnvjpeg-dev-11-8 libtinfo5 libxcb-icccm4
#   libxcb-image0 libxcb-keysyms1 libxcb-render-util0 libxcb-util1
#   libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxkbcommon-x11-0 libxtst6
#   libxxf86dga1 nsight-compute-2022.3.0 nsight-systems-2022.4.2 openjdk-11-jre
#   x11-utils
# Suggested packages:
#   mesa-utils
# The following NEW packages will be installed:
#   cuda-cccl-11-8 cuda-command-line-tools-11-8 cuda-compiler-11-8
#   cuda-cudart-11-8 cuda-cudart-dev-11-8 cuda-cuobjdump-11-8 cuda-cupti-11-8
#   cuda-cupti-dev-11-8 cuda-cuxxfilt-11-8 cuda-documentation-11-8
#   cuda-driver-dev-11-8 cuda-gdb-11-8 cuda-libraries-11-8
#   cuda-libraries-dev-11-8 cuda-memcheck-11-8 cuda-nsight-11-8
#   cuda-nsight-compute-11-8 cuda-nsight-systems-11-8 cuda-nvcc-11-8
#   cuda-nvdisasm-11-8 cuda-nvml-dev-11-8 cuda-nvprof-11-8 cuda-nvprune-11-8
#   cuda-nvrtc-11-8 cuda-nvrtc-dev-11-8 cuda-nvtx-11-8 cuda-nvvp-11-8
#   cuda-profiler-api-11-8 cuda-sanitizer-11-8 cuda-toolkit-11-8
#   cuda-toolkit-11-8-config-common cuda-toolkit-11-config-common
#   cuda-tools-11-8 cuda-visual-tools-11-8 default-jre default-jre-headless
#   fonts-dejavu-core fonts-dejavu-extra gds-tools-11-8 libatk-wrapper-java
#   libatk-wrapper-java-jni libcublas-11-8 libcublas-dev-11-8 libcufft-11-8
#   libcufft-dev-11-8 libcufile-11-8 libcufile-dev-11-8 libcurand-11-8
#   libcurand-dev-11-8 libcusolver-11-8 libcusolver-dev-11-8 libcusparse-11-8
#   libcusparse-dev-11-8 libnpp-11-8 libnpp-dev-11-8 libnvjpeg-11-8
#   libnvjpeg-dev-11-8 libtinfo5 libxcb-icccm4 libxcb-image0 libxcb-keysyms1
#   libxcb-render-util0 libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1
#   libxkbcommon-x11-0 libxtst6 libxxf86dga1 nsight-compute-2022.3.0
#   nsight-systems-2022.4.2 openjdk-11-jre x11-utils
# 0 upgraded, 73 newly installed, 0 to remove and 51 not upgraded.
# Need to get 2,715 MB of archives.
# After this operation, 6,662 MB of additional disk space will be used.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cccl-11-8 11.8.89-1 [1,040 kB]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cupti-11-8 11.8.87-1 [15.4 MB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre-headless amd64 2:1.11-72build2 [3,042 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cupti-dev-11-8 11.8.87-1 [2,552 kB]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvdisasm-11-8 11.8.86-1 [50.8 MB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre amd64 11.0.27+6~us1-0ubuntu1~22.04 [214 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cuobjdump-11-8 11.8.86-1 [165 kB]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-gdb-11-8 11.8.86-1 [4,138 kB]
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-memcheck-11-8 11.8.86-1 [142 kB]
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvprof-11-8 11.8.87-1 [1,959 kB]
# Get:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvtx-11-8 11.8.86-1 [51.3 kB]
# Get:13 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-sanitizer-11-8 11.8.86-1 [8,784 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre amd64 2:1.11-72build2 [896 B]
# Get:15 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-command-line-tools-11-8 11.8.0-1 [2,472 B]
# Get:16 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cuxxfilt-11-8 11.8.86-1 [189 kB]
# Get:17 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-toolkit-11-config-common 11.8.89-1 [16.4 kB]
# Get:18 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-toolkit-11-8-config-common 11.8.89-1 [16.3 kB]
# Get:19 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cudart-11-8 11.8.89-1 [165 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libtinfo5 amd64 6.3-2ubuntu0.1 [100 kB]
# Get:21 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-driver-dev-11-8 11.8.89-1 [27.3 kB]
# Get:22 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cudart-dev-11-8 11.8.89-1 [820 kB]
# Get:23 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvcc-11-8 11.8.89-1 [43.5 MB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build2 [11.5 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-keysyms1 amd64 0.4.0-1build3 [8,746 B]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xkb1 amd64 1.14-3ubuntu3 [32.8 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-x11-0 amd64 1.4.0-1 [14.4 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:34 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvprune-11-8 11.8.86-1 [58.1 kB]
# Get:35 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-compiler-11-8 11.8.0-1 [2,432 B]
# Get:36 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-documentation-11-8 11.8.86-1 [49.8 kB]
# Get:37 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvrtc-11-8 11.8.89-1 [16.4 MB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:39 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcublas-11-8 11.11.3.6-1 [248 MB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:44 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufft-11-8 10.9.0.58-1 [94.2 MB]
# Get:45 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufile-11-8 1.4.0.31-1 [474 kB]
# Get:46 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcurand-11-8 10.3.0.86-1 [42.2 MB]
# Get:47 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusolver-11-8 11.4.1.48-1 [52.3 MB]
# Get:48 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusparse-11-8 11.7.5.86-1 [116 MB]
# Get:49 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnpp-11-8 11.8.0.86-1 [102 MB]
# Get:50 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjpeg-11-8 11.9.0.86-1 [1,865 kB]
# Get:51 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-libraries-11-8 11.8.0-1 [2,518 B]
# Get:52 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-profiler-api-11-8 11.8.86-1 [18.5 kB]
# Get:53 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvrtc-dev-11-8 11.8.89-1 [13.5 MB]
# Get:54 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcublas-dev-11-8 11.11.3.6-1 [269 MB]
# Get:55 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufft-dev-11-8 10.9.0.58-1 [189 MB]
# Get:56 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufile-dev-11-8 1.4.0.31-1 [1,062 kB]
# Get:57 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcurand-dev-11-8 10.3.0.86-1 [42.9 MB]
# Get:58 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusolver-dev-11-8 11.4.1.48-1 [35.7 MB]
# Get:59 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusparse-dev-11-8 11.7.5.86-1 [116 MB]
# Get:60 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnpp-dev-11-8 11.8.0.86-1 [100 MB]
# Get:61 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjpeg-dev-11-8 11.9.0.86-1 [1,536 kB]
# Get:62 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-libraries-dev-11-8 11.8.0-1 [2,554 B]
# Get:63 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-11-8 11.8.86-1 [119 MB]
# Get:64 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nsight-compute-2022.3.0 2022.3.0.22-1 [580 MB]
# Get:65 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-compute-11-8 11.8.0-1 [3,790 B]
# Get:66 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nsight-systems-2022.4.2 2022.4.2.50-32196742v0 [286 MB]
# Get:67 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-systems-11-8 11.8.0-1 [3,310 B]
# Get:68 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvml-dev-11-8 11.8.86-1 [81.4 kB]
# Get:69 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvvp-11-8 11.8.87-1 [114 MB]
# Get:70 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-visual-tools-11-8 11.8.0-1 [2,870 B]
# Get:71 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  gds-tools-11-8 1.4.0.31-1 [38.7 MB]
# Get:72 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-tools-11-8 11.8.0-1 [2,390 B]
# Get:73 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-toolkit-11-8 11.8.0-1 [3,374 B]
# Fetched 2,715 MB in 36s (76.0 MB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package cuda-cccl-11-8.
# (Reading database ... 126281 files and directories currently installed.)
# Preparing to unpack .../00-cuda-cccl-11-8_11.8.89-1_amd64.deb ...
# Unpacking cuda-cccl-11-8 (11.8.89-1) ...
# Selecting previously unselected package cuda-cupti-11-8.
# Preparing to unpack .../01-cuda-cupti-11-8_11.8.87-1_amd64.deb ...
# Unpacking cuda-cupti-11-8 (11.8.87-1) ...
# Selecting previously unselected package cuda-cupti-dev-11-8.
# Preparing to unpack .../02-cuda-cupti-dev-11-8_11.8.87-1_amd64.deb ...
# Unpacking cuda-cupti-dev-11-8 (11.8.87-1) ...
# Selecting previously unselected package cuda-nvdisasm-11-8.
# Preparing to unpack .../03-cuda-nvdisasm-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-nvdisasm-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-cuobjdump-11-8.
# Preparing to unpack .../04-cuda-cuobjdump-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-cuobjdump-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-gdb-11-8.
# Preparing to unpack .../05-cuda-gdb-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-gdb-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-memcheck-11-8.
# Preparing to unpack .../06-cuda-memcheck-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-memcheck-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-nvprof-11-8.
# Preparing to unpack .../07-cuda-nvprof-11-8_11.8.87-1_amd64.deb ...
# Unpacking cuda-nvprof-11-8 (11.8.87-1) ...
# Selecting previously unselected package cuda-nvtx-11-8.
# Preparing to unpack .../08-cuda-nvtx-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-nvtx-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-sanitizer-11-8.
# Preparing to unpack .../09-cuda-sanitizer-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-sanitizer-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-command-line-tools-11-8.
# Preparing to unpack .../10-cuda-command-line-tools-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-command-line-tools-11-8 (11.8.0-1) ...
# Selecting previously unselected package cuda-cuxxfilt-11-8.
# Preparing to unpack .../11-cuda-cuxxfilt-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-cuxxfilt-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-toolkit-11-config-common.
# Preparing to unpack .../12-cuda-toolkit-11-config-common_11.8.89-1_all.deb ...
# Unpacking cuda-toolkit-11-config-common (11.8.89-1) ...
# Selecting previously unselected package cuda-toolkit-11-8-config-common.
# Preparing to unpack .../13-cuda-toolkit-11-8-config-common_11.8.89-1_all.deb ...
# Unpacking cuda-toolkit-11-8-config-common (11.8.89-1) ...
# Selecting previously unselected package cuda-cudart-11-8.
# Preparing to unpack .../14-cuda-cudart-11-8_11.8.89-1_amd64.deb ...
# Unpacking cuda-cudart-11-8 (11.8.89-1) ...
# Selecting previously unselected package cuda-driver-dev-11-8.
# Preparing to unpack .../15-cuda-driver-dev-11-8_11.8.89-1_amd64.deb ...
# Unpacking cuda-driver-dev-11-8 (11.8.89-1) ...
# Selecting previously unselected package cuda-cudart-dev-11-8.
# Preparing to unpack .../16-cuda-cudart-dev-11-8_11.8.89-1_amd64.deb ...
# Unpacking cuda-cudart-dev-11-8 (11.8.89-1) ...
# Selecting previously unselected package cuda-nvcc-11-8.
# Preparing to unpack .../17-cuda-nvcc-11-8_11.8.89-1_amd64.deb ...
# Unpacking cuda-nvcc-11-8 (11.8.89-1) ...
# Selecting previously unselected package cuda-nvprune-11-8.
# Preparing to unpack .../18-cuda-nvprune-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-nvprune-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-compiler-11-8.
# Preparing to unpack .../19-cuda-compiler-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-compiler-11-8 (11.8.0-1) ...
# Selecting previously unselected package cuda-documentation-11-8.
# Preparing to unpack .../20-cuda-documentation-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-documentation-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-nvrtc-11-8.
# Preparing to unpack .../21-cuda-nvrtc-11-8_11.8.89-1_amd64.deb ...
# Unpacking cuda-nvrtc-11-8 (11.8.89-1) ...
# Selecting previously unselected package libcublas-11-8.
# Preparing to unpack .../22-libcublas-11-8_11.11.3.6-1_amd64.deb ...
# Unpacking libcublas-11-8 (11.11.3.6-1) ...
# Selecting previously unselected package libcufft-11-8.
# Preparing to unpack .../23-libcufft-11-8_10.9.0.58-1_amd64.deb ...
# Unpacking libcufft-11-8 (10.9.0.58-1) ...
# Selecting previously unselected package libcufile-11-8.
# Preparing to unpack .../24-libcufile-11-8_1.4.0.31-1_amd64.deb ...
# Unpacking libcufile-11-8 (1.4.0.31-1) ...
# Selecting previously unselected package libcurand-11-8.
# Preparing to unpack .../25-libcurand-11-8_10.3.0.86-1_amd64.deb ...
# Unpacking libcurand-11-8 (10.3.0.86-1) ...
# Selecting previously unselected package libcusolver-11-8.
# Preparing to unpack .../26-libcusolver-11-8_11.4.1.48-1_amd64.deb ...
# Unpacking libcusolver-11-8 (11.4.1.48-1) ...
# Selecting previously unselected package libcusparse-11-8.
# Preparing to unpack .../27-libcusparse-11-8_11.7.5.86-1_amd64.deb ...
# Unpacking libcusparse-11-8 (11.7.5.86-1) ...
# Selecting previously unselected package libnpp-11-8.
# Preparing to unpack .../28-libnpp-11-8_11.8.0.86-1_amd64.deb ...
# Unpacking libnpp-11-8 (11.8.0.86-1) ...
# Selecting previously unselected package libnvjpeg-11-8.
# Preparing to unpack .../29-libnvjpeg-11-8_11.9.0.86-1_amd64.deb ...
# Unpacking libnvjpeg-11-8 (11.9.0.86-1) ...
# Selecting previously unselected package cuda-libraries-11-8.
# Preparing to unpack .../30-cuda-libraries-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-libraries-11-8 (11.8.0-1) ...
# Selecting previously unselected package cuda-profiler-api-11-8.
# Preparing to unpack .../31-cuda-profiler-api-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-profiler-api-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-nvrtc-dev-11-8.
# Preparing to unpack .../32-cuda-nvrtc-dev-11-8_11.8.89-1_amd64.deb ...
# Unpacking cuda-nvrtc-dev-11-8 (11.8.89-1) ...
# Selecting previously unselected package libcublas-dev-11-8.
# Preparing to unpack .../33-libcublas-dev-11-8_11.11.3.6-1_amd64.deb ...
# Unpacking libcublas-dev-11-8 (11.11.3.6-1) ...
# Selecting previously unselected package libcufft-dev-11-8.
# Preparing to unpack .../34-libcufft-dev-11-8_10.9.0.58-1_amd64.deb ...
# Unpacking libcufft-dev-11-8 (10.9.0.58-1) ...
# Selecting previously unselected package libcufile-dev-11-8.
# Preparing to unpack .../35-libcufile-dev-11-8_1.4.0.31-1_amd64.deb ...
# Unpacking libcufile-dev-11-8 (1.4.0.31-1) ...
# Selecting previously unselected package libcurand-dev-11-8.
# Preparing to unpack .../36-libcurand-dev-11-8_10.3.0.86-1_amd64.deb ...
# Unpacking libcurand-dev-11-8 (10.3.0.86-1) ...
# Selecting previously unselected package libcusolver-dev-11-8.
# Preparing to unpack .../37-libcusolver-dev-11-8_11.4.1.48-1_amd64.deb ...
# Unpacking libcusolver-dev-11-8 (11.4.1.48-1) ...
# Selecting previously unselected package libcusparse-dev-11-8.
# Preparing to unpack .../38-libcusparse-dev-11-8_11.7.5.86-1_amd64.deb ...
# Unpacking libcusparse-dev-11-8 (11.7.5.86-1) ...
# Selecting previously unselected package libnpp-dev-11-8.
# Preparing to unpack .../39-libnpp-dev-11-8_11.8.0.86-1_amd64.deb ...
# Unpacking libnpp-dev-11-8 (11.8.0.86-1) ...
# Selecting previously unselected package libnvjpeg-dev-11-8.
# Preparing to unpack .../40-libnvjpeg-dev-11-8_11.9.0.86-1_amd64.deb ...
# Unpacking libnvjpeg-dev-11-8 (11.9.0.86-1) ...
# Selecting previously unselected package cuda-libraries-dev-11-8.
# Preparing to unpack .../41-cuda-libraries-dev-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-libraries-dev-11-8 (11.8.0-1) ...
# Selecting previously unselected package default-jre-headless.
# Preparing to unpack .../42-default-jre-headless_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre-headless (2:1.11-72build2) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../43-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package openjdk-11-jre:amd64.
# Preparing to unpack .../44-openjdk-11-jre_11.0.27+6~us1-0ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.27+6~us1-0ubuntu1~22.04) ...
# Selecting previously unselected package default-jre.
# Preparing to unpack .../45-default-jre_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre (2:1.11-72build2) ...
# Selecting previously unselected package cuda-nsight-11-8.
# Preparing to unpack .../46-cuda-nsight-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-nsight-11-8 (11.8.86-1) ...
# Selecting previously unselected package nsight-compute-2022.3.0.
# Preparing to unpack .../47-nsight-compute-2022.3.0_2022.3.0.22-1_amd64.deb ...
# Unpacking nsight-compute-2022.3.0 (2022.3.0.22-1) ...
# Selecting previously unselected package cuda-nsight-compute-11-8.
# Preparing to unpack .../48-cuda-nsight-compute-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-nsight-compute-11-8 (11.8.0-1) ...
# Selecting previously unselected package libtinfo5:amd64.
# Preparing to unpack .../49-libtinfo5_6.3-2ubuntu0.1_amd64.deb ...
# Unpacking libtinfo5:amd64 (6.3-2ubuntu0.1) ...
# Selecting previously unselected package libxcb-xinerama0:amd64.
# Preparing to unpack .../50-libxcb-xinerama0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-icccm4:amd64.
# Preparing to unpack .../51-libxcb-icccm4_0.4.1-1.1build2_amd64.deb ...
# Unpacking libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Selecting previously unselected package libxcb-util1:amd64.
# Preparing to unpack .../52-libxcb-util1_0.4.0-1build2_amd64.deb ...
# Unpacking libxcb-util1:amd64 (0.4.0-1build2) ...
# Selecting previously unselected package libxcb-image0:amd64.
# Preparing to unpack .../53-libxcb-image0_0.4.0-2_amd64.deb ...
# Unpacking libxcb-image0:amd64 (0.4.0-2) ...
# Selecting previously unselected package libxcb-keysyms1:amd64.
# Preparing to unpack .../54-libxcb-keysyms1_0.4.0-1build3_amd64.deb ...
# Unpacking libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Selecting previously unselected package libxcb-render-util0:amd64.
# Preparing to unpack .../55-libxcb-render-util0_0.3.9-1build3_amd64.deb ...
# Unpacking libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Selecting previously unselected package libxcb-xkb1:amd64.
# Preparing to unpack .../56-libxcb-xkb1_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxkbcommon-x11-0:amd64.
# Preparing to unpack .../57-libxkbcommon-x11-0_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Selecting previously unselected package libxcb-xinput0:amd64.
# Preparing to unpack .../58-libxcb-xinput0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package nsight-systems-2022.4.2.
# Preparing to unpack .../59-nsight-systems-2022.4.2_2022.4.2.50-32196742v0_amd64.deb ...
# Unpacking nsight-systems-2022.4.2 (2022.4.2.50-32196742v0) ...
# Selecting previously unselected package cuda-nsight-systems-11-8.
# Preparing to unpack .../60-cuda-nsight-systems-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-nsight-systems-11-8 (11.8.0-1) ...
# Selecting previously unselected package cuda-nvml-dev-11-8.
# Preparing to unpack .../61-cuda-nvml-dev-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-nvml-dev-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-nvvp-11-8.
# Preparing to unpack .../62-cuda-nvvp-11-8_11.8.87-1_amd64.deb ...
# Unpacking cuda-nvvp-11-8 (11.8.87-1) ...
# Selecting previously unselected package cuda-visual-tools-11-8.
# Preparing to unpack .../63-cuda-visual-tools-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-visual-tools-11-8 (11.8.0-1) ...
# Selecting previously unselected package gds-tools-11-8.
# Preparing to unpack .../64-gds-tools-11-8_1.4.0.31-1_amd64.deb ...
# Unpacking gds-tools-11-8 (1.4.0.31-1) ...
# Selecting previously unselected package cuda-tools-11-8.
# Preparing to unpack .../65-cuda-tools-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-tools-11-8 (11.8.0-1) ...
# Selecting previously unselected package cuda-toolkit-11-8.
# Preparing to unpack .../66-cuda-toolkit-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-toolkit-11-8 (11.8.0-1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../67-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../68-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../69-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../70-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../71-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../72-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up cuda-nvml-dev-11-8 (11.8.86-1) ...
# Setting up default-jre-headless (2:1.11-72build2) ...
# Setting up cuda-toolkit-11-config-common (11.8.89-1) ...
# Setting up libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Setting up cuda-cccl-11-8 (11.8.89-1) ...
# Setting up cuda-cuobjdump-11-8 (11.8.86-1) ...
# Setting up cuda-nvrtc-11-8 (11.8.89-1) ...
# Setting up cuda-sanitizer-11-8 (11.8.86-1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up cuda-cupti-11-8 (11.8.87-1) ...
# Setting up libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Setting up openjdk-11-jre:amd64 (11.0.27+6~us1-0ubuntu1~22.04) ...
# Setting up cuda-nvdisasm-11-8 (11.8.86-1) ...
# Setting up libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Setting up default-jre (2:1.11-72build2) ...
# Setting up cuda-cuxxfilt-11-8 (11.8.86-1) ...
# Setting up libxcb-util1:amd64 (0.4.0-1build2) ...
# Setting up libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Setting up libxcb-image0:amd64 (0.4.0-2) ...
# Setting up libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Setting up cuda-nvvp-11-8 (11.8.87-1) ...
# Setting up cuda-nvtx-11-8 (11.8.86-1) ...
# Setting up cuda-gdb-11-8 (11.8.86-1) ...
# Setting up cuda-toolkit-11-8-config-common (11.8.89-1) ...
# Setting alternatives
# update-alternatives: warning: forcing reinstallation of alternative /usr/local/cuda-12.5 because link group cuda is broken
# update-alternatives: using /usr/local/cuda-11.8 to provide /usr/local/cuda-11 (cuda-11) in auto mode
# Setting up libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Setting up libcusolver-11-8 (11.4.1.48-1) ...
# Setting up cuda-nvrtc-dev-11-8 (11.8.89-1) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up cuda-driver-dev-11-8 (11.8.89-1) ...
# Setting up cuda-memcheck-11-8 (11.8.86-1) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up gds-tools-11-8 (1.4.0.31-1) ...
# Setting up cuda-nsight-11-8 (11.8.86-1) ...
# Setting up cuda-profiler-api-11-8 (11.8.86-1) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up cuda-documentation-11-8 (11.8.86-1) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up libtinfo5:amd64 (6.3-2ubuntu0.1) ...
# Setting up cuda-nvprune-11-8 (11.8.86-1) ...
# Setting up cuda-cudart-11-8 (11.8.89-1) ...
# Setting up libnvjpeg-11-8 (11.9.0.86-1) ...
# Setting up cuda-nvprof-11-8 (11.8.87-1) ...
# Setting up nsight-compute-2022.3.0 (2022.3.0.22-1) ...
# Setting up nsight-systems-2022.4.2 (2022.4.2.50-32196742v0) ...
# update-alternatives: using /opt/nvidia/nsight-systems/2022.4.2/target-linux-x64/nsys to provide /usr/local/bin/nsys (nsys) in auto mode
# update-alternatives: using /opt/nvidia/nsight-systems/2022.4.2/host-linux-x64/nsys-ui to provide /usr/local/bin/nsys-ui (nsys-ui) in auto mode
# Setting up libcusparse-11-8 (11.7.5.86-1) ...
# Setting up libcufft-11-8 (10.9.0.58-1) ...
# Setting up cuda-cupti-dev-11-8 (11.8.87-1) ...
# Setting up libcufft-dev-11-8 (10.9.0.58-1) ...
# Setting up cuda-cudart-dev-11-8 (11.8.89-1) ...
# Setting up libnpp-11-8 (11.8.0.86-1) ...
# Setting up libcusolver-dev-11-8 (11.4.1.48-1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up cuda-nsight-systems-11-8 (11.8.0-1) ...
# Setting up cuda-command-line-tools-11-8 (11.8.0-1) ...
# Setting up libcusparse-dev-11-8 (11.7.5.86-1) ...
# Setting up libcurand-11-8 (10.3.0.86-1) ...
# Setting up libcufile-11-8 (1.4.0.31-1) ...
# Setting alternatives
# Setting up libcublas-11-8 (11.11.3.6-1) ...
# Setting up libnpp-dev-11-8 (11.8.0.86-1) ...
# Setting up cuda-libraries-11-8 (11.8.0-1) ...
# Setting up cuda-nsight-compute-11-8 (11.8.0-1) ...
# Setting up libnvjpeg-dev-11-8 (11.9.0.86-1) ...
# Setting up cuda-nvcc-11-8 (11.8.89-1) ...
# Setting up libcublas-dev-11-8 (11.11.3.6-1) ...
# Setting up libcurand-dev-11-8 (10.3.0.86-1) ...
# Setting up libcufile-dev-11-8 (1.4.0.31-1) ...
# Setting up cuda-compiler-11-8 (11.8.0-1) ...
# Setting up cuda-libraries-dev-11-8 (11.8.0-1) ...
# Setting up cuda-visual-tools-11-8 (11.8.0-1) ...
# Setting up cuda-tools-11-8 (11.8.0-1) ...
# Setting up cuda-toolkit-11-8 (11.8.0-1) ...
# Setting alternatives
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0

# %%
# !nvcc -arch=sm_75 01_idxing.cu -o 01_idxing

# %%
# !./01_idxing
# Out:
# 24 blocks/grid
# 64 threads/block
# 1536 total threads
# 1216 | Block(1 0 3) =  19 | Thread(0 0 0) =   0
# 1217 | Block(1 0 3) =  19 | Thread(1 0 0) =   1
# 1218 | Block(1 0 3) =  19 | Thread(2 0 0) =   2
# 1219 | Block(1 0 3) =  19 | Thread(3 0 0) =   3
# 1220 | Block(1 0 3) =  19 | Thread(0 1 0) =   4
# 1221 | Block(1 0 3) =  19 | Thread(1 1 0) =   5
# 1222 | Block(1 0 3) =  19 | Thread(2 1 0) =   6
# 1223 | Block(1 0 3) =  19 | Thread(3 1 0) =   7
# 1224 | Block(1 0 3) =  19 | Thread(0 2 0) =   8
# 1225 | Block(1 0 3) =  19 | Thread(1 2 0) =   9
# 1226 | Block(1 0 3) =  19 | Thread(2 2 0) =  10
# 1227 | Block(1 0 3) =  19 | Thread(3 2 0) =  11
# 1228 | Block(1 0 3) =  19 | Thread(0 3 0) =  12
# 1229 | Block(1 0 3) =  19 | Thread(1 3 0) =  13
# 1230 | Block(1 0 3) =  19 | Thread(2 3 0) =  14
# 1231 | Block(1 0 3) =  19 | Thread(3 3 0) =  15
# 1232 | Block(1 0 3) =  19 | Thread(0 0 1) =  16
# 1233 | Block(1 0 3) =  19 | Thread(1 0 1) =  17
# 1234 | Block(1 0 3) =  19 | Thread(2 0 1) =  18
# 1235 | Block(1 0 3) =  19 | Thread(3 0 1) =  19
# 1236 | Block(1 0 3) =  19 | Thread(0 1 1) =  20
# 1237 | Block(1 0 3) =  19 | Thread(1 1 1) =  21
# 1238 | Block(1 0 3) =  19 | Thread(2 1 1) =  22
# 1239 | Block(1 0 3) =  19 | Thread(3 1 1) =  23
# 1240 | Block(1 0 3) =  19 | Thread(0 2 1) =  24
# 1241 | Block(1 0 3) =  19 | Thread(1 2 1) =  25
# 1242 | Block(1 0 3) =  19 | Thread(2 2 1) =  26
# 1243 | Block(1 0 3) =  19 | Thread(3 2 1) =  27
# 1244 | Block(1 0 3) =  19 | Thread(0 3 1) =  28
# 1245 | Block(1 0 3) =  19 | Thread(1 3 1) =  29
# 1246 | Block(1 0 3) =  19 | Thread(2 3 1) =  30
# 1247 | Block(1 0 3) =  19 | Thread(3 3 1) =  31
# 1248 | Block(1 0 3) =  19 | Thread(0 0 2) =  32
# 1249 | Block(1 0 3) =  19 | Thread(1 0 2) =  33
# 1250 | Block(1 0 3) =  19 | Thread(2 0 2) =  34
# 1251 | Block(1 0 3) =  19 | Thread(3 0 2) =  35
# 1252 | Block(1 0 3) =  19 | Thread(0 1 2) =  36
# 1253 | Block(1 0 3) =  19 | Thread(1 1 2) =  37
# 1254 | Block(1 0 3) =  19 | Thread(2 1 2) =  38
# 1255 | Block(1 0 3) =  19 | Thread(3 1 2) =  39
# 1256 | Block(1 0 3) =  19 | Thread(0 2 2) =  40
# 1257 | Block(1 0 3) =  19 | Thread(1 2 2) =  41
# 1258 | Block(1 0 3) =  19 | Thread(2 2 2) =  42
# 1259 | Block(1 0 3) =  19 | Thread(3 2 2) =  43
# 1260 | Block(1 0 3) =  19 | Thread(0 3 2) =  44
# 1261 | Block(1 0 3) =  19 | Thread(1 3 2) =  45
# 1262 | Block(1 0 3) =  19 | Thread(2 3 2) =  46
# 1263 | Block(1 0 3) =  19 | Thread(3 3 2) =  47
# 1264 | Block(1 0 3) =  19 | Thread(0 0 3) =  48
# 1265 | Block(1 0 3) =  19 | Thread(1 0 3) =  49
# 1266 | Block(1 0 3) =  19 | Thread(2 0 3) =  50
# 1267 | Block(1 0 3) =  19 | Thread(3 0 3) =  51
# 1268 | Block(1 0 3) =  19 | Thread(0 1 3) =  52
# 1269 | Block(1 0 3) =  19 | Thread(1 1 3) =  53
# 1270 | Block(1 0 3) =  19 | Thread(2 1 3) =  54
# 1271 | Block(1 0 3) =  19 | Thread(3 1 3) =  55
# 1272 | Block(1 0 3) =  19 | Thread(0 2 3) =  56
# 1273 | Block(1 0 3) =  19 | Thread(1 2 3) =  57
# 1274 | Block(1 0 3) =  19 | Thread(2 2 3) =  58
# 1275 | Block(1 0 3) =  19 | Thread(3 2 3) =  59
# 1276 | Block(1 0 3) =  19 | Thread(0 3 3) =  60
# 1277 | Block(1 0 3) =  19 | Thread(1 3 3) =  61
# 1278 | Block(1 0 3) =  19 | Thread(2 3 3) =  62
# 1279 | Block(1 0 3) =  19 | Thread(3 3 3) =  63
# 0896 | Block(0 1 2) =  14 | Thread(0 0 0) =   0
# 0897 | Block(0 1 2) =  14 | Thread(1 0 0) =   1
# 0898 | Block(0 1 2) =  14 | Thread(2 0 0) =   2
# 0899 | Block(0 1 2) =  14 | Thread(3 0 0) =   3
# 0900 | Block(0 1 2) =  14 | Thread(0 1 0) =   4
# 0901 | Block(0 1 2) =  14 | Thread(1 1 0) =   5
# 0902 | Block(0 1 2) =  14 | Thread(2 1 0) =   6
# 0903 | Block(0 1 2) =  14 | Thread(3 1 0) =   7
# 0904 | Block(0 1 2) =  14 | Thread(0 2 0) =   8
# 0905 | Block(0 1 2) =  14 | Thread(1 2 0) =   9
# 0906 | Block(0 1 2) =  14 | Thread(2 2 0) =  10
# 0907 | Block(0 1 2) =  14 | Thread(3 2 0) =  11
# 0908 | Block(0 1 2) =  14 | Thread(0 3 0) =  12
# 0909 | Block(0 1 2) =  14 | Thread(1 3 0) =  13
# 0910 | Block(0 1 2) =  14 | Thread(2 3 0) =  14
# 0911 | Block(0 1 2) =  14 | Thread(3 3 0) =  15
# 0912 | Block(0 1 2) =  14 | Thread(0 0 1) =  16
# 0913 | Block(0 1 2) =  14 | Thread(1 0 1) =  17
# 0914 | Block(0 1 2) =  14 | Thread(2 0 1) =  18
# 0915 | Block(0 1 2) =  14 | Thread(3 0 1) =  19
# 0916 | Block(0 1 2) =  14 | Thread(0 1 1) =  20
# 0917 | Block(0 1 2) =  14 | Thread(1 1 1) =  21
# 0918 | Block(0 1 2) =  14 | Thread(2 1 1) =  22
# 0919 | Block(0 1 2) =  14 | Thread(3 1 1) =  23
# 0920 | Block(0 1 2) =  14 | Thread(0 2 1) =  24
# 0921 | Block(0 1 2) =  14 | Thread(1 2 1) =  25
# 0922 | Block(0 1 2) =  14 | Thread(2 2 1) =  26
# 0923 | Block(0 1 2) =  14 | Thread(3 2 1) =  27
# 0924 | Block(0 1 2) =  14 | Thread(0 3 1) =  28
# 0925 | Block(0 1 2) =  14 | Thread(1 3 1) =  29
# 0926 | Block(0 1 2) =  14 | Thread(2 3 1) =  30
# 0927 | Block(0 1 2) =  14 | Thread(3 3 1) =  31
# 0928 | Block(0 1 2) =  14 | Thread(0 0 2) =  32
# 0929 | Block(0 1 2) =  14 | Thread(1 0 2) =  33
# 0930 | Block(0 1 2) =  14 | Thread(2 0 2) =  34
# 0931 | Block(0 1 2) =  14 | Thread(3 0 2) =  35
# 0932 | Block(0 1 2) =  14 | Thread(0 1 2) =  36
# 0933 | Block(0 1 2) =  14 | Thread(1 1 2) =  37
# 0934 | Block(0 1 2) =  14 | Thread(2 1 2) =  38
# 0935 | Block(0 1 2) =  14 | Thread(3 1 2) =  39
# 0936 | Block(0 1 2) =  14 | Thread(0 2 2) =  40
# 0937 | Block(0 1 2) =  14 | Thread(1 2 2) =  41
# 0938 | Block(0 1 2) =  14 | Thread(2 2 2) =  42
# 0939 | Block(0 1 2) =  14 | Thread(3 2 2) =  43
# 0940 | Block(0 1 2) =  14 | Thread(0 3 2) =  44
# 0941 | Block(0 1 2) =  14 | Thread(1 3 2) =  45
# 0942 | Block(0 1 2) =  14 | Thread(2 3 2) =  46
# 0943 | Block(0 1 2) =  14 | Thread(3 3 2) =  47
# 0944 | Block(0 1 2) =  14 | Thread(0 0 3) =  48
# 0945 | Block(0 1 2) =  14 | Thread(1 0 3) =  49
# 0946 | Block(0 1 2) =  14 | Thread(2 0 3) =  50
# 0947 | Block(0 1 2) =  14 | Thread(3 0 3) =  51
# 0948 | Block(0 1 2) =  14 | Thread(0 1 3) =  52
# 0949 | Block(0 1 2) =  14 | Thread(1 1 3) =  53
# 0950 | Block(0 1 2) =  14 | Thread(2 1 3) =  54
# 0951 | Block(0 1 2) =  14 | Thread(3 1 3) =  55
# 0952 | Block(0 1 2) =  14 | Thread(0 2 3) =  56
# 0953 | Block(0 1 2) =  14 | Thread(1 2 3) =  57
# 0954 | Block(0 1 2) =  14 | Thread(2 2 3) =  58
# 0955 | Block(0 1 2) =  14 | Thread(3 2 3) =  59
# 0956 | Block(0 1 2) =  14 | Thread(0 3 3) =  60
# 0957 | Block(0 1 2) =  14 | Thread(1 3 3) =  61
# 0958 | Block(0 1 2) =  14 | Thread(2 3 3) =  62
# 0959 | Block(0 1 2) =  14 | Thread(3 3 3) =  63
# 1088 | Block(1 2 2) =  17 | Thread(0 0 0) =   0
# 1089 | Block(1 2 2) =  17 | Thread(1 0 0) =   1
# 1090 | Block(1 2 2) =  17 | Thread(2 0 0) =   2
# 1091 | Block(1 2 2) =  17 | Thread(3 0 0) =   3
# 1092 | Block(1 2 2) =  17 | Thread(0 1 0) =   4
# 1093 | Block(1 2 2) =  17 | Thread(1 1 0) =   5
# 1094 | Block(1 2 2) =  17 | Thread(2 1 0) =   6
# 1095 | Block(1 2 2) =  17 | Thread(3 1 0) =   7
# 1096 | Block(1 2 2) =  17 | Thread(0 2 0) =   8
# 1097 | Block(1 2 2) =  17 | Thread(1 2 0) =   9
# 1098 | Block(1 2 2) =  17 | Thread(2 2 0) =  10
# 1099 | Block(1 2 2) =  17 | Thread(3 2 0) =  11
# 1100 | Block(1 2 2) =  17 | Thread(0 3 0) =  12
# 1101 | Block(1 2 2) =  17 | Thread(1 3 0) =  13
# 1102 | Block(1 2 2) =  17 | Thread(2 3 0) =  14
# 1103 | Block(1 2 2) =  17 | Thread(3 3 0) =  15
# 1104 | Block(1 2 2) =  17 | Thread(0 0 1) =  16
# 1105 | Block(1 2 2) =  17 | Thread(1 0 1) =  17
# 1106 | Block(1 2 2) =  17 | Thread(2 0 1) =  18
# 1107 | Block(1 2 2) =  17 | Thread(3 0 1) =  19
# 1108 | Block(1 2 2) =  17 | Thread(0 1 1) =  20
# 1109 | Block(1 2 2) =  17 | Thread(1 1 1) =  21
# 1110 | Block(1 2 2) =  17 | Thread(2 1 1) =  22
# 1111 | Block(1 2 2) =  17 | Thread(3 1 1) =  23
# 1112 | Block(1 2 2) =  17 | Thread(0 2 1) =  24
# 1113 | Block(1 2 2) =  17 | Thread(1 2 1) =  25
# 1114 | Block(1 2 2) =  17 | Thread(2 2 1) =  26
# 1115 | Block(1 2 2) =  17 | Thread(3 2 1) =  27
# 1116 | Block(1 2 2) =  17 | Thread(0 3 1) =  28
# 1117 | Block(1 2 2) =  17 | Thread(1 3 1) =  29
# 1118 | Block(1 2 2) =  17 | Thread(2 3 1) =  30
# 1119 | Block(1 2 2) =  17 | Thread(3 3 1) =  31
# 1120 | Block(1 2 2) =  17 | Thread(0 0 2) =  32
# 1121 | Block(1 2 2) =  17 | Thread(1 0 2) =  33
# 1122 | Block(1 2 2) =  17 | Thread(2 0 2) =  34
# 1123 | Block(1 2 2) =  17 | Thread(3 0 2) =  35
# 1124 | Block(1 2 2) =  17 | Thread(0 1 2) =  36
# 1125 | Block(1 2 2) =  17 | Thread(1 1 2) =  37
# 1126 | Block(1 2 2) =  17 | Thread(2 1 2) =  38
# 1127 | Block(1 2 2) =  17 | Thread(3 1 2) =  39
# 1128 | Block(1 2 2) =  17 | Thread(0 2 2) =  40
# 1129 | Block(1 2 2) =  17 | Thread(1 2 2) =  41
# 1130 | Block(1 2 2) =  17 | Thread(2 2 2) =  42
# 1131 | Block(1 2 2) =  17 | Thread(3 2 2) =  43
# 1132 | Block(1 2 2) =  17 | Thread(0 3 2) =  44
# 1133 | Block(1 2 2) =  17 | Thread(1 3 2) =  45
# 1134 | Block(1 2 2) =  17 | Thread(2 3 2) =  46
# 1135 | Block(1 2 2) =  17 | Thread(3 3 2) =  47
# 1136 | Block(1 2 2) =  17 | Thread(0 0 3) =  48
# 1137 | Block(1 2 2) =  17 | Thread(1 0 3) =  49
# 1138 | Block(1 2 2) =  17 | Thread(2 0 3) =  50
# 1139 | Block(1 2 2) =  17 | Thread(3 0 3) =  51
# 1140 | Block(1 2 2) =  17 | Thread(0 1 3) =  52
# 1141 | Block(1 2 2) =  17 | Thread(1 1 3) =  53
# 1142 | Block(1 2 2) =  17 | Thread(2 1 3) =  54
# 1143 | Block(1 2 2) =  17 | Thread(3 1 3) =  55
# 1144 | Block(1 2 2) =  17 | Thread(0 2 3) =  56
# 1145 | Block(1 2 2) =  17 | Thread(1 2 3) =  57
# 1146 | Block(1 2 2) =  17 | Thread(2 2 3) =  58
# 1147 | Block(1 2 2) =  17 | Thread(3 2 3) =  59
# 1148 | Block(1 2 2) =  17 | Thread(0 3 3) =  60
# 1149 | Block(1 2 2) =  17 | Thread(1 3 3) =  61
# 1150 | Block(1 2 2) =  17 | Thread(2 3 3) =  62
# 1151 | Block(1 2 2) =  17 | Thread(3 3 3) =  63
# 0768 | Block(0 0 2) =  12 | Thread(0 0 0) =   0
# 0769 | Block(0 0 2) =  12 | Thread(1 0 0) =   1
# 0770 | Block(0 0 2) =  12 | Thread(2 0 0) =   2
# 0771 | Block(0 0 2) =  12 | Thread(3 0 0) =   3
# 0772 | Block(0 0 2) =  12 | Thread(0 1 0) =   4
# 0773 | Block(0 0 2) =  12 | Thread(1 1 0) =   5
# 0774 | Block(0 0 2) =  12 | Thread(2 1 0) =   6
# 0775 | Block(0 0 2) =  12 | Thread(3 1 0) =   7
# 0776 | Block(0 0 2) =  12 | Thread(0 2 0) =   8
# 0777 | Block(0 0 2) =  12 | Thread(1 2 0) =   9
# 0778 | Block(0 0 2) =  12 | Thread(2 2 0) =  10
# 0779 | Block(0 0 2) =  12 | Thread(3 2 0) =  11
# 0780 | Block(0 0 2) =  12 | Thread(0 3 0) =  12
# 0781 | Block(0 0 2) =  12 | Thread(1 3 0) =  13
# 0782 | Block(0 0 2) =  12 | Thread(2 3 0) =  14
# 0783 | Block(0 0 2) =  12 | Thread(3 3 0) =  15
# 0784 | Block(0 0 2) =  12 | Thread(0 0 1) =  16
# 0785 | Block(0 0 2) =  12 | Thread(1 0 1) =  17
# 0786 | Block(0 0 2) =  12 | Thread(2 0 1) =  18
# 0787 | Block(0 0 2) =  12 | Thread(3 0 1) =  19
# 0788 | Block(0 0 2) =  12 | Thread(0 1 1) =  20
# 0789 | Block(0 0 2) =  12 | Thread(1 1 1) =  21
# 0790 | Block(0 0 2) =  12 | Thread(2 1 1) =  22
# 0791 | Block(0 0 2) =  12 | Thread(3 1 1) =  23
# 0792 | Block(0 0 2) =  12 | Thread(0 2 1) =  24
# 0793 | Block(0 0 2) =  12 | Thread(1 2 1) =  25
# 0794 | Block(0 0 2) =  12 | Thread(2 2 1) =  26
# 0795 | Block(0 0 2) =  12 | Thread(3 2 1) =  27
# 0796 | Block(0 0 2) =  12 | Thread(0 3 1) =  28
# 0797 | Block(0 0 2) =  12 | Thread(1 3 1) =  29
# 0798 | Block(0 0 2) =  12 | Thread(2 3 1) =  30
# 0799 | Block(0 0 2) =  12 | Thread(3 3 1) =  31
# 0800 | Block(0 0 2) =  12 | Thread(0 0 2) =  32
# 0801 | Block(0 0 2) =  12 | Thread(1 0 2) =  33
# 0802 | Block(0 0 2) =  12 | Thread(2 0 2) =  34
# 0803 | Block(0 0 2) =  12 | Thread(3 0 2) =  35
# 0804 | Block(0 0 2) =  12 | Thread(0 1 2) =  36
# 0805 | Block(0 0 2) =  12 | Thread(1 1 2) =  37
# 0806 | Block(0 0 2) =  12 | Thread(2 1 2) =  38
# 0807 | Block(0 0 2) =  12 | Thread(3 1 2) =  39
# 0808 | Block(0 0 2) =  12 | Thread(0 2 2) =  40
# 0809 | Block(0 0 2) =  12 | Thread(1 2 2) =  41
# 0810 | Block(0 0 2) =  12 | Thread(2 2 2) =  42
# 0811 | Block(0 0 2) =  12 | Thread(3 2 2) =  43
# 0812 | Block(0 0 2) =  12 | Thread(0 3 2) =  44
# 0813 | Block(0 0 2) =  12 | Thread(1 3 2) =  45
# 0814 | Block(0 0 2) =  12 | Thread(2 3 2) =  46
# 0815 | Block(0 0 2) =  12 | Thread(3 3 2) =  47
# 0816 | Block(0 0 2) =  12 | Thread(0 0 3) =  48
# 0817 | Block(0 0 2) =  12 | Thread(1 0 3) =  49
# 0818 | Block(0 0 2) =  12 | Thread(2 0 3) =  50
# 0819 | Block(0 0 2) =  12 | Thread(3 0 3) =  51
# 0820 | Block(0 0 2) =  12 | Thread(0 1 3) =  52
# 0821 | Block(0 0 2) =  12 | Thread(1 1 3) =  53
# 0822 | Block(0 0 2) =  12 | Thread(2 1 3) =  54
# 0823 | Block(0 0 2) =  12 | Thread(3 1 3) =  55
# 0824 | Block(0 0 2) =  12 | Thread(0 2 3) =  56
# 0825 | Block(0 0 2) =  12 | Thread(1 2 3) =  57
# 0826 | Block(0 0 2) =  12 | Thread(2 2 3) =  58
# 0827 | Block(0 0 2) =  12 | Thread(3 2 3) =  59
# 0828 | Block(0 0 2) =  12 | Thread(0 3 3) =  60
# 0829 | Block(0 0 2) =  12 | Thread(1 3 3) =  61
# 0830 | Block(0 0 2) =  12 | Thread(2 3 3) =  62
# 0831 | Block(0 0 2) =  12 | Thread(3 3 3) =  63
# 0576 | Block(1 1 1) =   9 | Thread(0 0 0) =   0
# 0577 | Block(1 1 1) =   9 | Thread(1 0 0) =   1
# 0578 | Block(1 1 1) =   9 | Thread(2 0 0) =   2
# 0579 | Block(1 1 1) =   9 | Thread(3 0 0) =   3
# 0580 | Block(1 1 1) =   9 | Thread(0 1 0) =   4
# 0581 | Block(1 1 1) =   9 | Thread(1 1 0) =   5
# 0582 | Block(1 1 1) =   9 | Thread(2 1 0) =   6
# 0583 | Block(1 1 1) =   9 | Thread(3 1 0) =   7
# 0584 | Block(1 1 1) =   9 | Thread(0 2 0) =   8
# 0585 | Block(1 1 1) =   9 | Thread(1 2 0) =   9
# 0586 | Block(1 1 1) =   9 | Thread(2 2 0) =  10
# 0587 | Block(1 1 1) =   9 | Thread(3 2 0) =  11
# 0588 | Block(1 1 1) =   9 | Thread(0 3 0) =  12
# 0589 | Block(1 1 1) =   9 | Thread(1 3 0) =  13
# 0590 | Block(1 1 1) =   9 | Thread(2 3 0) =  14
# 0591 | Block(1 1 1) =   9 | Thread(3 3 0) =  15
# 0592 | Block(1 1 1) =   9 | Thread(0 0 1) =  16
# 0593 | Block(1 1 1) =   9 | Thread(1 0 1) =  17
# 0594 | Block(1 1 1) =   9 | Thread(2 0 1) =  18
# 0595 | Block(1 1 1) =   9 | Thread(3 0 1) =  19
# 0596 | Block(1 1 1) =   9 | Thread(0 1 1) =  20
# 0597 | Block(1 1 1) =   9 | Thread(1 1 1) =  21
# 0598 | Block(1 1 1) =   9 | Thread(2 1 1) =  22
# 0599 | Block(1 1 1) =   9 | Thread(3 1 1) =  23
# 0600 | Block(1 1 1) =   9 | Thread(0 2 1) =  24
# 0601 | Block(1 1 1) =   9 | Thread(1 2 1) =  25
# 0602 | Block(1 1 1) =   9 | Thread(2 2 1) =  26
# 0603 | Block(1 1 1) =   9 | Thread(3 2 1) =  27
# 0604 | Block(1 1 1) =   9 | Thread(0 3 1) =  28
# 0605 | Block(1 1 1) =   9 | Thread(1 3 1) =  29
# 0606 | Block(1 1 1) =   9 | Thread(2 3 1) =  30
# 0607 | Block(1 1 1) =   9 | Thread(3 3 1) =  31
# 0608 | Block(1 1 1) =   9 | Thread(0 0 2) =  32
# 0609 | Block(1 1 1) =   9 | Thread(1 0 2) =  33
# 0610 | Block(1 1 1) =   9 | Thread(2 0 2) =  34
# 0611 | Block(1 1 1) =   9 | Thread(3 0 2) =  35
# 0612 | Block(1 1 1) =   9 | Thread(0 1 2) =  36
# 0613 | Block(1 1 1) =   9 | Thread(1 1 2) =  37
# 0614 | Block(1 1 1) =   9 | Thread(2 1 2) =  38
# 0615 | Block(1 1 1) =   9 | Thread(3 1 2) =  39
# 0616 | Block(1 1 1) =   9 | Thread(0 2 2) =  40
# 0617 | Block(1 1 1) =   9 | Thread(1 2 2) =  41
# 0618 | Block(1 1 1) =   9 | Thread(2 2 2) =  42
# 0619 | Block(1 1 1) =   9 | Thread(3 2 2) =  43
# 0620 | Block(1 1 1) =   9 | Thread(0 3 2) =  44
# 0621 | Block(1 1 1) =   9 | Thread(1 3 2) =  45
# 0622 | Block(1 1 1) =   9 | Thread(2 3 2) =  46
# 0623 | Block(1 1 1) =   9 | Thread(3 3 2) =  47
# 0624 | Block(1 1 1) =   9 | Thread(0 0 3) =  48
# 0625 | Block(1 1 1) =   9 | Thread(1 0 3) =  49
# 0626 | Block(1 1 1) =   9 | Thread(2 0 3) =  50
# 0627 | Block(1 1 1) =   9 | Thread(3 0 3) =  51
# 0628 | Block(1 1 1) =   9 | Thread(0 1 3) =  52
# 0629 | Block(1 1 1) =   9 | Thread(1 1 3) =  53
# 0630 | Block(1 1 1) =   9 | Thread(2 1 3) =  54
# 0631 | Block(1 1 1) =   9 | Thread(3 1 3) =  55
# 0632 | Block(1 1 1) =   9 | Thread(0 2 3) =  56
# 0633 | Block(1 1 1) =   9 | Thread(1 2 3) =  57
# 0634 | Block(1 1 1) =   9 | Thread(2 2 3) =  58
# 0635 | Block(1 1 1) =   9 | Thread(3 2 3) =  59
# 0636 | Block(1 1 1) =   9 | Thread(0 3 3) =  60
# 0637 | Block(1 1 1) =   9 | Thread(1 3 3) =  61
# 0638 | Block(1 1 1) =   9 | Thread(2 3 3) =  62
# 0639 | Block(1 1 1) =   9 | Thread(3 3 3) =  63
# 1152 | Block(0 0 3) =  18 | Thread(0 0 0) =   0
# 1153 | Block(0 0 3) =  18 | Thread(1 0 0) =   1
# 1154 | Block(0 0 3) =  18 | Thread(2 0 0) =   2
# 1155 | Block(0 0 3) =  18 | Thread(3 0 0) =   3
# 1156 | Block(0 0 3) =  18 | Thread(0 1 0) =   4
# 1157 | Block(0 0 3) =  18 | Thread(1 1 0) =   5
# 1158 | Block(0 0 3) =  18 | Thread(2 1 0) =   6
# 1159 | Block(0 0 3) =  18 | Thread(3 1 0) =   7
# 1160 | Block(0 0 3) =  18 | Thread(0 2 0) =   8
# 1161 | Block(0 0 3) =  18 | Thread(1 2 0) =   9
# 1162 | Block(0 0 3) =  18 | Thread(2 2 0) =  10
# 1163 | Block(0 0 3) =  18 | Thread(3 2 0) =  11
# 1164 | Block(0 0 3) =  18 | Thread(0 3 0) =  12
# 1165 | Block(0 0 3) =  18 | Thread(1 3 0) =  13
# 1166 | Block(0 0 3) =  18 | Thread(2 3 0) =  14
# 1167 | Block(0 0 3) =  18 | Thread(3 3 0) =  15
# 1168 | Block(0 0 3) =  18 | Thread(0 0 1) =  16
# 1169 | Block(0 0 3) =  18 | Thread(1 0 1) =  17
# 1170 | Block(0 0 3) =  18 | Thread(2 0 1) =  18
# 1171 | Block(0 0 3) =  18 | Thread(3 0 1) =  19
# 1172 | Block(0 0 3) =  18 | Thread(0 1 1) =  20
# 1173 | Block(0 0 3) =  18 | Thread(1 1 1) =  21
# 1174 | Block(0 0 3) =  18 | Thread(2 1 1) =  22
# 1175 | Block(0 0 3) =  18 | Thread(3 1 1) =  23
# 1176 | Block(0 0 3) =  18 | Thread(0 2 1) =  24
# 1177 | Block(0 0 3) =  18 | Thread(1 2 1) =  25
# 1178 | Block(0 0 3) =  18 | Thread(2 2 1) =  26
# 1179 | Block(0 0 3) =  18 | Thread(3 2 1) =  27
# 1180 | Block(0 0 3) =  18 | Thread(0 3 1) =  28
# 1181 | Block(0 0 3) =  18 | Thread(1 3 1) =  29
# 1182 | Block(0 0 3) =  18 | Thread(2 3 1) =  30
# 1183 | Block(0 0 3) =  18 | Thread(3 3 1) =  31
# 1184 | Block(0 0 3) =  18 | Thread(0 0 2) =  32
# 1185 | Block(0 0 3) =  18 | Thread(1 0 2) =  33
# 1186 | Block(0 0 3) =  18 | Thread(2 0 2) =  34
# 1187 | Block(0 0 3) =  18 | Thread(3 0 2) =  35
# 1188 | Block(0 0 3) =  18 | Thread(0 1 2) =  36
# 1189 | Block(0 0 3) =  18 | Thread(1 1 2) =  37
# 1190 | Block(0 0 3) =  18 | Thread(2 1 2) =  38
# 1191 | Block(0 0 3) =  18 | Thread(3 1 2) =  39
# 1192 | Block(0 0 3) =  18 | Thread(0 2 2) =  40
# 1193 | Block(0 0 3) =  18 | Thread(1 2 2) =  41
# 1194 | Block(0 0 3) =  18 | Thread(2 2 2) =  42
# 1195 | Block(0 0 3) =  18 | Thread(3 2 2) =  43
# 1196 | Block(0 0 3) =  18 | Thread(0 3 2) =  44
# 1197 | Block(0 0 3) =  18 | Thread(1 3 2) =  45
# 1198 | Block(0 0 3) =  18 | Thread(2 3 2) =  46
# 1199 | Block(0 0 3) =  18 | Thread(3 3 2) =  47
# 1200 | Block(0 0 3) =  18 | Thread(0 0 3) =  48
# 1201 | Block(0 0 3) =  18 | Thread(1 0 3) =  49
# 1202 | Block(0 0 3) =  18 | Thread(2 0 3) =  50
# 1203 | Block(0 0 3) =  18 | Thread(3 0 3) =  51
# 1204 | Block(0 0 3) =  18 | Thread(0 1 3) =  52
# 1205 | Block(0 0 3) =  18 | Thread(1 1 3) =  53
# 1206 | Block(0 0 3) =  18 | Thread(2 1 3) =  54
# 1207 | Block(0 0 3) =  18 | Thread(3 1 3) =  55
# 1208 | Block(0 0 3) =  18 | Thread(0 2 3) =  56
# 1209 | Block(0 0 3) =  18 | Thread(1 2 3) =  57
# 1210 | Block(0 0 3) =  18 | Thread(2 2 3) =  58
# 1211 | Block(0 0 3) =  18 | Thread(3 2 3) =  59
# 1212 | Block(0 0 3) =  18 | Thread(0 3 3) =  60
# 1213 | Block(0 0 3) =  18 | Thread(1 3 3) =  61
# 1214 | Block(0 0 3) =  18 | Thread(2 3 3) =  62
# 1215 | Block(0 0 3) =  18 | Thread(3 3 3) =  63
# 0448 | Block(1 0 1) =   7 | Thread(0 0 0) =   0
# 0449 | Block(1 0 1) =   7 | Thread(1 0 0) =   1
# 0450 | Block(1 0 1) =   7 | Thread(2 0 0) =   2
# 0451 | Block(1 0 1) =   7 | Thread(3 0 0) =   3
# 0452 | Block(1 0 1) =   7 | Thread(0 1 0) =   4
# 0453 | Block(1 0 1) =   7 | Thread(1 1 0) =   5
# 0454 | Block(1 0 1) =   7 | Thread(2 1 0) =   6
# 0455 | Block(1 0 1) =   7 | Thread(3 1 0) =   7
# 0456 | Block(1 0 1) =   7 | Thread(0 2 0) =   8
# 0457 | Block(1 0 1) =   7 | Thread(1 2 0) =   9
# 0458 | Block(1 0 1) =   7 | Thread(2 2 0) =  10
# 0459 | Block(1 0 1) =   7 | Thread(3 2 0) =  11
# 0460 | Block(1 0 1) =   7 | Thread(0 3 0) =  12
# 0461 | Block(1 0 1) =   7 | Thread(1 3 0) =  13
# 0462 | Block(1 0 1) =   7 | Thread(2 3 0) =  14
# 0463 | Block(1 0 1) =   7 | Thread(3 3 0) =  15
# 0464 | Block(1 0 1) =   7 | Thread(0 0 1) =  16
# 0465 | Block(1 0 1) =   7 | Thread(1 0 1) =  17
# 0466 | Block(1 0 1) =   7 | Thread(2 0 1) =  18
# 0467 | Block(1 0 1) =   7 | Thread(3 0 1) =  19
# 0468 | Block(1 0 1) =   7 | Thread(0 1 1) =  20
# 0469 | Block(1 0 1) =   7 | Thread(1 1 1) =  21
# 0470 | Block(1 0 1) =   7 | Thread(2 1 1) =  22
# 0471 | Block(1 0 1) =   7 | Thread(3 1 1) =  23
# 0472 | Block(1 0 1) =   7 | Thread(0 2 1) =  24
# 0473 | Block(1 0 1) =   7 | Thread(1 2 1) =  25
# 0474 | Block(1 0 1) =   7 | Thread(2 2 1) =  26
# 0475 | Block(1 0 1) =   7 | Thread(3 2 1) =  27
# 0476 | Block(1 0 1) =   7 | Thread(0 3 1) =  28
# 0477 | Block(1 0 1) =   7 | Thread(1 3 1) =  29
# 0478 | Block(1 0 1) =   7 | Thread(2 3 1) =  30
# 0479 | Block(1 0 1) =   7 | Thread(3 3 1) =  31
# 0480 | Block(1 0 1) =   7 | Thread(0 0 2) =  32
# 0481 | Block(1 0 1) =   7 | Thread(1 0 2) =  33
# 0482 | Block(1 0 1) =   7 | Thread(2 0 2) =  34
# 0483 | Block(1 0 1) =   7 | Thread(3 0 2) =  35
# 0484 | Block(1 0 1) =   7 | Thread(0 1 2) =  36
# 0485 | Block(1 0 1) =   7 | Thread(1 1 2) =  37
# 0486 | Block(1 0 1) =   7 | Thread(2 1 2) =  38
# 0487 | Block(1 0 1) =   7 | Thread(3 1 2) =  39
# 0488 | Block(1 0 1) =   7 | Thread(0 2 2) =  40
# 0489 | Block(1 0 1) =   7 | Thread(1 2 2) =  41
# 0490 | Block(1 0 1) =   7 | Thread(2 2 2) =  42
# 0491 | Block(1 0 1) =   7 | Thread(3 2 2) =  43
# 0492 | Block(1 0 1) =   7 | Thread(0 3 2) =  44
# 0493 | Block(1 0 1) =   7 | Thread(1 3 2) =  45
# 0494 | Block(1 0 1) =   7 | Thread(2 3 2) =  46
# 0495 | Block(1 0 1) =   7 | Thread(3 3 2) =  47
# 0496 | Block(1 0 1) =   7 | Thread(0 0 3) =  48
# 0497 | Block(1 0 1) =   7 | Thread(1 0 3) =  49
# 0498 | Block(1 0 1) =   7 | Thread(2 0 3) =  50
# 0499 | Block(1 0 1) =   7 | Thread(3 0 3) =  51
# 0500 | Block(1 0 1) =   7 | Thread(0 1 3) =  52
# 0501 | Block(1 0 1) =   7 | Thread(1 1 3) =  53
# 0502 | Block(1 0 1) =   7 | Thread(2 1 3) =  54
# 0503 | Block(1 0 1) =   7 | Thread(3 1 3) =  55
# 0504 | Block(1 0 1) =   7 | Thread(0 2 3) =  56
# 0505 | Block(1 0 1) =   7 | Thread(1 2 3) =  57
# 0506 | Block(1 0 1) =   7 | Thread(2 2 3) =  58
# 0507 | Block(1 0 1) =   7 | Thread(3 2 3) =  59
# 0508 | Block(1 0 1) =   7 | Thread(0 3 3) =  60
# 0509 | Block(1 0 1) =   7 | Thread(1 3 3) =  61
# 0510 | Block(1 0 1) =   7 | Thread(2 3 3) =  62
# 0511 | Block(1 0 1) =   7 | Thread(3 3 3) =  63
# 0256 | Block(0 2 0) =   4 | Thread(0 0 0) =   0
# 0257 | Block(0 2 0) =   4 | Thread(1 0 0) =   1
# 0258 | Block(0 2 0) =   4 | Thread(2 0 0) =   2
# 0259 | Block(0 2 0) =   4 | Thread(3 0 0) =   3
# 0260 | Block(0 2 0) =   4 | Thread(0 1 0) =   4
# 0261 | Block(0 2 0) =   4 | Thread(1 1 0) =   5
# 0262 | Block(0 2 0) =   4 | Thread(2 1 0) =   6
# 0263 | Block(0 2 0) =   4 | Thread(3 1 0) =   7
# 0264 | Block(0 2 0) =   4 | Thread(0 2 0) =   8
# 0265 | Block(0 2 0) =   4 | Thread(1 2 0) =   9
# 0266 | Block(0 2 0) =   4 | Thread(2 2 0) =  10
# 0267 | Block(0 2 0) =   4 | Thread(3 2 0) =  11
# 0268 | Block(0 2 0) =   4 | Thread(0 3 0) =  12
# 0269 | Block(0 2 0) =   4 | Thread(1 3 0) =  13
# 0270 | Block(0 2 0) =   4 | Thread(2 3 0) =  14
# 0271 | Block(0 2 0) =   4 | Thread(3 3 0) =  15
# 0272 | Block(0 2 0) =   4 | Thread(0 0 1) =  16
# 0273 | Block(0 2 0) =   4 | Thread(1 0 1) =  17
# 0274 | Block(0 2 0) =   4 | Thread(2 0 1) =  18
# 0275 | Block(0 2 0) =   4 | Thread(3 0 1) =  19
# 0276 | Block(0 2 0) =   4 | Thread(0 1 1) =  20
# 0277 | Block(0 2 0) =   4 | Thread(1 1 1) =  21
# 0278 | Block(0 2 0) =   4 | Thread(2 1 1) =  22
# 0279 | Block(0 2 0) =   4 | Thread(3 1 1) =  23
# 0280 | Block(0 2 0) =   4 | Thread(0 2 1) =  24
# 0281 | Block(0 2 0) =   4 | Thread(1 2 1) =  25
# 0282 | Block(0 2 0) =   4 | Thread(2 2 1) =  26
# 0283 | Block(0 2 0) =   4 | Thread(3 2 1) =  27
# 0284 | Block(0 2 0) =   4 | Thread(0 3 1) =  28
# 0285 | Block(0 2 0) =   4 | Thread(1 3 1) =  29
# 0286 | Block(0 2 0) =   4 | Thread(2 3 1) =  30
# 0287 | Block(0 2 0) =   4 | Thread(3 3 1) =  31
# 0288 | Block(0 2 0) =   4 | Thread(0 0 2) =  32
# 0289 | Block(0 2 0) =   4 | Thread(1 0 2) =  33
# 0290 | Block(0 2 0) =   4 | Thread(2 0 2) =  34
# 0291 | Block(0 2 0) =   4 | Thread(3 0 2) =  35
# 0292 | Block(0 2 0) =   4 | Thread(0 1 2) =  36
# 0293 | Block(0 2 0) =   4 | Thread(1 1 2) =  37
# 0294 | Block(0 2 0) =   4 | Thread(2 1 2) =  38
# 0295 | Block(0 2 0) =   4 | Thread(3 1 2) =  39
# 0296 | Block(0 2 0) =   4 | Thread(0 2 2) =  40
# 0297 | Block(0 2 0) =   4 | Thread(1 2 2) =  41
# 0298 | Block(0 2 0) =   4 | Thread(2 2 2) =  42
# 0299 | Block(0 2 0) =   4 | Thread(3 2 2) =  43
# 0300 | Block(0 2 0) =   4 | Thread(0 3 2) =  44
# 0301 | Block(0 2 0) =   4 | Thread(1 3 2) =  45
# 0302 | Block(0 2 0) =   4 | Thread(2 3 2) =  46
# 0303 | Block(0 2 0) =   4 | Thread(3 3 2) =  47
# 0304 | Block(0 2 0) =   4 | Thread(0 0 3) =  48
# 0305 | Block(0 2 0) =   4 | Thread(1 0 3) =  49
# 0306 | Block(0 2 0) =   4 | Thread(2 0 3) =  50
# 0307 | Block(0 2 0) =   4 | Thread(3 0 3) =  51
# 0308 | Block(0 2 0) =   4 | Thread(0 1 3) =  52
# 0309 | Block(0 2 0) =   4 | Thread(1 1 3) =  53
# 0310 | Block(0 2 0) =   4 | Thread(2 1 3) =  54
# 0311 | Block(0 2 0) =   4 | Thread(3 1 3) =  55
# 0312 | Block(0 2 0) =   4 | Thread(0 2 3) =  56
# 0313 | Block(0 2 0) =   4 | Thread(1 2 3) =  57
# 0314 | Block(0 2 0) =   4 | Thread(2 2 3) =  58
# 0315 | Block(0 2 0) =   4 | Thread(3 2 3) =  59
# 0316 | Block(0 2 0) =   4 | Thread(0 3 3) =  60
# 0317 | Block(0 2 0) =   4 | Thread(1 3 3) =  61
# 0318 | Block(0 2 0) =   4 | Thread(2 3 3) =  62
# 0319 | Block(0 2 0) =   4 | Thread(3 3 3) =  63
# 0960 | Block(1 1 2) =  15 | Thread(0 0 0) =   0
# 0961 | Block(1 1 2) =  15 | Thread(1 0 0) =   1
# 0962 | Block(1 1 2) =  15 | Thread(2 0 0) =   2
# 0963 | Block(1 1 2) =  15 | Thread(3 0 0) =   3
# 0964 | Block(1 1 2) =  15 | Thread(0 1 0) =   4
# 0965 | Block(1 1 2) =  15 | Thread(1 1 0) =   5
# 0966 | Block(1 1 2) =  15 | Thread(2 1 0) =   6
# 0967 | Block(1 1 2) =  15 | Thread(3 1 0) =   7
# 0968 | Block(1 1 2) =  15 | Thread(0 2 0) =   8
# 0969 | Block(1 1 2) =  15 | Thread(1 2 0) =   9
# 0970 | Block(1 1 2) =  15 | Thread(2 2 0) =  10
# 0971 | Block(1 1 2) =  15 | Thread(3 2 0) =  11
# 0972 | Block(1 1 2) =  15 | Thread(0 3 0) =  12
# 0973 | Block(1 1 2) =  15 | Thread(1 3 0) =  13
# 0974 | Block(1 1 2) =  15 | Thread(2 3 0) =  14
# 0975 | Block(1 1 2) =  15 | Thread(3 3 0) =  15
# 0976 | Block(1 1 2) =  15 | Thread(0 0 1) =  16
# 0977 | Block(1 1 2) =  15 | Thread(1 0 1) =  17
# 0978 | Block(1 1 2) =  15 | Thread(2 0 1) =  18
# 0979 | Block(1 1 2) =  15 | Thread(3 0 1) =  19
# 0980 | Block(1 1 2) =  15 | Thread(0 1 1) =  20
# 0981 | Block(1 1 2) =  15 | Thread(1 1 1) =  21
# 0982 | Block(1 1 2) =  15 | Thread(2 1 1) =  22
# 0983 | Block(1 1 2) =  15 | Thread(3 1 1) =  23
# 0984 | Block(1 1 2) =  15 | Thread(0 2 1) =  24
# 0985 | Block(1 1 2) =  15 | Thread(1 2 1) =  25
# 0986 | Block(1 1 2) =  15 | Thread(2 2 1) =  26
# 0987 | Block(1 1 2) =  15 | Thread(3 2 1) =  27
# 0988 | Block(1 1 2) =  15 | Thread(0 3 1) =  28
# 0989 | Block(1 1 2) =  15 | Thread(1 3 1) =  29
# 0990 | Block(1 1 2) =  15 | Thread(2 3 1) =  30
# 0991 | Block(1 1 2) =  15 | Thread(3 3 1) =  31
# 0992 | Block(1 1 2) =  15 | Thread(0 0 2) =  32
# 0993 | Block(1 1 2) =  15 | Thread(1 0 2) =  33
# 0994 | Block(1 1 2) =  15 | Thread(2 0 2) =  34
# 0995 | Block(1 1 2) =  15 | Thread(3 0 2) =  35
# 0996 | Block(1 1 2) =  15 | Thread(0 1 2) =  36
# 0997 | Block(1 1 2) =  15 | Thread(1 1 2) =  37
# 0998 | Block(1 1 2) =  15 | Thread(2 1 2) =  38
# 0999 | Block(1 1 2) =  15 | Thread(3 1 2) =  39
# 1000 | Block(1 1 2) =  15 | Thread(0 2 2) =  40
# 1001 | Block(1 1 2) =  15 | Thread(1 2 2) =  41
# 1002 | Block(1 1 2) =  15 | Thread(2 2 2) =  42
# 1003 | Block(1 1 2) =  15 | Thread(3 2 2) =  43
# 1004 | Block(1 1 2) =  15 | Thread(0 3 2) =  44
# 1005 | Block(1 1 2) =  15 | Thread(1 3 2) =  45
# 1006 | Block(1 1 2) =  15 | Thread(2 3 2) =  46
# 1007 | Block(1 1 2) =  15 | Thread(3 3 2) =  47
# 1008 | Block(1 1 2) =  15 | Thread(0 0 3) =  48
# 1009 | Block(1 1 2) =  15 | Thread(1 0 3) =  49
# 1010 | Block(1 1 2) =  15 | Thread(2 0 3) =  50
# 1011 | Block(1 1 2) =  15 | Thread(3 0 3) =  51
# 1012 | Block(1 1 2) =  15 | Thread(0 1 3) =  52
# 1013 | Block(1 1 2) =  15 | Thread(1 1 3) =  53
# 1014 | Block(1 1 2) =  15 | Thread(2 1 3) =  54
# 1015 | Block(1 1 2) =  15 | Thread(3 1 3) =  55
# 1016 | Block(1 1 2) =  15 | Thread(0 2 3) =  56
# 1017 | Block(1 1 2) =  15 | Thread(1 2 3) =  57
# 1018 | Block(1 1 2) =  15 | Thread(2 2 3) =  58
# 1019 | Block(1 1 2) =  15 | Thread(3 2 3) =  59
# 1020 | Block(1 1 2) =  15 | Thread(0 3 3) =  60
# 1021 | Block(1 1 2) =  15 | Thread(1 3 3) =  61
# 1022 | Block(1 1 2) =  15 | Thread(2 3 3) =  62
# 1023 | Block(1 1 2) =  15 | Thread(3 3 3) =  63
# 0832 | Block(1 0 2) =  13 | Thread(0 0 0) =   0
# 0833 | Block(1 0 2) =  13 | Thread(1 0 0) =   1
# 0834 | Block(1 0 2) =  13 | Thread(2 0 0) =   2
# 0835 | Block(1 0 2) =  13 | Thread(3 0 0) =   3
# 0836 | Block(1 0 2) =  13 | Thread(0 1 0) =   4
# 0837 | Block(1 0 2) =  13 | Thread(1 1 0) =   5
# 0838 | Block(1 0 2) =  13 | Thread(2 1 0) =   6
# 0839 | Block(1 0 2) =  13 | Thread(3 1 0) =   7
# 0840 | Block(1 0 2) =  13 | Thread(0 2 0) =   8
# 0841 | Block(1 0 2) =  13 | Thread(1 2 0) =   9
# 0842 | Block(1 0 2) =  13 | Thread(2 2 0) =  10
# 0843 | Block(1 0 2) =  13 | Thread(3 2 0) =  11
# 0844 | Block(1 0 2) =  13 | Thread(0 3 0) =  12
# 0845 | Block(1 0 2) =  13 | Thread(1 3 0) =  13
# 0846 | Block(1 0 2) =  13 | Thread(2 3 0) =  14
# 0847 | Block(1 0 2) =  13 | Thread(3 3 0) =  15
# 0848 | Block(1 0 2) =  13 | Thread(0 0 1) =  16
# 0849 | Block(1 0 2) =  13 | Thread(1 0 1) =  17
# 0850 | Block(1 0 2) =  13 | Thread(2 0 1) =  18
# 0851 | Block(1 0 2) =  13 | Thread(3 0 1) =  19
# 0852 | Block(1 0 2) =  13 | Thread(0 1 1) =  20
# 0853 | Block(1 0 2) =  13 | Thread(1 1 1) =  21
# 0854 | Block(1 0 2) =  13 | Thread(2 1 1) =  22
# 0855 | Block(1 0 2) =  13 | Thread(3 1 1) =  23
# 0856 | Block(1 0 2) =  13 | Thread(0 2 1) =  24
# 0857 | Block(1 0 2) =  13 | Thread(1 2 1) =  25
# 0858 | Block(1 0 2) =  13 | Thread(2 2 1) =  26
# 0859 | Block(1 0 2) =  13 | Thread(3 2 1) =  27
# 0860 | Block(1 0 2) =  13 | Thread(0 3 1) =  28
# 0861 | Block(1 0 2) =  13 | Thread(1 3 1) =  29
# 0862 | Block(1 0 2) =  13 | Thread(2 3 1) =  30
# 0863 | Block(1 0 2) =  13 | Thread(3 3 1) =  31
# 0864 | Block(1 0 2) =  13 | Thread(0 0 2) =  32
# 0865 | Block(1 0 2) =  13 | Thread(1 0 2) =  33
# 0866 | Block(1 0 2) =  13 | Thread(2 0 2) =  34
# 0867 | Block(1 0 2) =  13 | Thread(3 0 2) =  35
# 0868 | Block(1 0 2) =  13 | Thread(0 1 2) =  36
# 0869 | Block(1 0 2) =  13 | Thread(1 1 2) =  37
# 0870 | Block(1 0 2) =  13 | Thread(2 1 2) =  38
# 0871 | Block(1 0 2) =  13 | Thread(3 1 2) =  39
# 0872 | Block(1 0 2) =  13 | Thread(0 2 2) =  40
# 0873 | Block(1 0 2) =  13 | Thread(1 2 2) =  41
# 0874 | Block(1 0 2) =  13 | Thread(2 2 2) =  42
# 0875 | Block(1 0 2) =  13 | Thread(3 2 2) =  43
# 0876 | Block(1 0 2) =  13 | Thread(0 3 2) =  44
# 0877 | Block(1 0 2) =  13 | Thread(1 3 2) =  45
# 0878 | Block(1 0 2) =  13 | Thread(2 3 2) =  46
# 0879 | Block(1 0 2) =  13 | Thread(3 3 2) =  47
# 0880 | Block(1 0 2) =  13 | Thread(0 0 3) =  48
# 0881 | Block(1 0 2) =  13 | Thread(1 0 3) =  49
# 0882 | Block(1 0 2) =  13 | Thread(2 0 3) =  50
# 0883 | Block(1 0 2) =  13 | Thread(3 0 3) =  51
# 0884 | Block(1 0 2) =  13 | Thread(0 1 3) =  52
# 0885 | Block(1 0 2) =  13 | Thread(1 1 3) =  53
# 0886 | Block(1 0 2) =  13 | Thread(2 1 3) =  54
# 0887 | Block(1 0 2) =  13 | Thread(3 1 3) =  55
# 0888 | Block(1 0 2) =  13 | Thread(0 2 3) =  56
# 0889 | Block(1 0 2) =  13 | Thread(1 2 3) =  57
# 0890 | Block(1 0 2) =  13 | Thread(2 2 3) =  58
# 0891 | Block(1 0 2) =  13 | Thread(3 2 3) =  59
# 0892 | Block(1 0 2) =  13 | Thread(0 3 3) =  60
# 0893 | Block(1 0 2) =  13 | Thread(1 3 3) =  61
# 0894 | Block(1 0 2) =  13 | Thread(2 3 3) =  62
# 0895 | Block(1 0 2) =  13 | Thread(3 3 3) =  63
# 0640 | Block(0 2 1) =  10 | Thread(0 0 0) =   0
# 0641 | Block(0 2 1) =  10 | Thread(1 0 0) =   1
# 0642 | Block(0 2 1) =  10 | Thread(2 0 0) =   2
# 0643 | Block(0 2 1) =  10 | Thread(3 0 0) =   3
# 0644 | Block(0 2 1) =  10 | Thread(0 1 0) =   4
# 0645 | Block(0 2 1) =  10 | Thread(1 1 0) =   5
# 0646 | Block(0 2 1) =  10 | Thread(2 1 0) =   6
# 0647 | Block(0 2 1) =  10 | Thread(3 1 0) =   7
# 0648 | Block(0 2 1) =  10 | Thread(0 2 0) =   8
# 0649 | Block(0 2 1) =  10 | Thread(1 2 0) =   9
# 0650 | Block(0 2 1) =  10 | Thread(2 2 0) =  10
# 0651 | Block(0 2 1) =  10 | Thread(3 2 0) =  11
# 0652 | Block(0 2 1) =  10 | Thread(0 3 0) =  12
# 0653 | Block(0 2 1) =  10 | Thread(1 3 0) =  13
# 0654 | Block(0 2 1) =  10 | Thread(2 3 0) =  14
# 0655 | Block(0 2 1) =  10 | Thread(3 3 0) =  15
# 0656 | Block(0 2 1) =  10 | Thread(0 0 1) =  16
# 0657 | Block(0 2 1) =  10 | Thread(1 0 1) =  17
# 0658 | Block(0 2 1) =  10 | Thread(2 0 1) =  18
# 0659 | Block(0 2 1) =  10 | Thread(3 0 1) =  19
# 0660 | Block(0 2 1) =  10 | Thread(0 1 1) =  20
# 0661 | Block(0 2 1) =  10 | Thread(1 1 1) =  21
# 0662 | Block(0 2 1) =  10 | Thread(2 1 1) =  22
# 0663 | Block(0 2 1) =  10 | Thread(3 1 1) =  23
# 0664 | Block(0 2 1) =  10 | Thread(0 2 1) =  24
# 0665 | Block(0 2 1) =  10 | Thread(1 2 1) =  25
# 0666 | Block(0 2 1) =  10 | Thread(2 2 1) =  26
# 0667 | Block(0 2 1) =  10 | Thread(3 2 1) =  27
# 0668 | Block(0 2 1) =  10 | Thread(0 3 1) =  28
# 0669 | Block(0 2 1) =  10 | Thread(1 3 1) =  29
# 0670 | Block(0 2 1) =  10 | Thread(2 3 1) =  30
# 0671 | Block(0 2 1) =  10 | Thread(3 3 1) =  31
# 0672 | Block(0 2 1) =  10 | Thread(0 0 2) =  32
# 0673 | Block(0 2 1) =  10 | Thread(1 0 2) =  33
# 0674 | Block(0 2 1) =  10 | Thread(2 0 2) =  34
# 0675 | Block(0 2 1) =  10 | Thread(3 0 2) =  35
# 0676 | Block(0 2 1) =  10 | Thread(0 1 2) =  36
# 0677 | Block(0 2 1) =  10 | Thread(1 1 2) =  37
# 0678 | Block(0 2 1) =  10 | Thread(2 1 2) =  38
# 0679 | Block(0 2 1) =  10 | Thread(3 1 2) =  39
# 0680 | Block(0 2 1) =  10 | Thread(0 2 2) =  40
# 0681 | Block(0 2 1) =  10 | Thread(1 2 2) =  41
# 0682 | Block(0 2 1) =  10 | Thread(2 2 2) =  42
# 0683 | Block(0 2 1) =  10 | Thread(3 2 2) =  43
# 0684 | Block(0 2 1) =  10 | Thread(0 3 2) =  44
# 0685 | Block(0 2 1) =  10 | Thread(1 3 2) =  45
# 0686 | Block(0 2 1) =  10 | Thread(2 3 2) =  46
# 0687 | Block(0 2 1) =  10 | Thread(3 3 2) =  47
# 0688 | Block(0 2 1) =  10 | Thread(0 0 3) =  48
# 0689 | Block(0 2 1) =  10 | Thread(1 0 3) =  49
# 0690 | Block(0 2 1) =  10 | Thread(2 0 3) =  50
# 0691 | Block(0 2 1) =  10 | Thread(3 0 3) =  51
# 0692 | Block(0 2 1) =  10 | Thread(0 1 3) =  52
# 0693 | Block(0 2 1) =  10 | Thread(1 1 3) =  53
# 0694 | Block(0 2 1) =  10 | Thread(2 1 3) =  54
# 0695 | Block(0 2 1) =  10 | Thread(3 1 3) =  55
# 0696 | Block(0 2 1) =  10 | Thread(0 2 3) =  56
# 0697 | Block(0 2 1) =  10 | Thread(1 2 3) =  57
# 0698 | Block(0 2 1) =  10 | Thread(2 2 3) =  58
# 0699 | Block(0 2 1) =  10 | Thread(3 2 3) =  59
# 0700 | Block(0 2 1) =  10 | Thread(0 3 3) =  60
# 0701 | Block(0 2 1) =  10 | Thread(1 3 3) =  61
# 0702 | Block(0 2 1) =  10 | Thread(2 3 3) =  62
# 0703 | Block(0 2 1) =  10 | Thread(3 3 3) =  63
# 0128 | Block(0 1 0) =   2 | Thread(0 0 0) =   0
# 0129 | Block(0 1 0) =   2 | Thread(1 0 0) =   1
# 0130 | Block(0 1 0) =   2 | Thread(2 0 0) =   2
# 0131 | Block(0 1 0) =   2 | Thread(3 0 0) =   3
# 0132 | Block(0 1 0) =   2 | Thread(0 1 0) =   4
# 0133 | Block(0 1 0) =   2 | Thread(1 1 0) =   5
# 0134 | Block(0 1 0) =   2 | Thread(2 1 0) =   6
# 0135 | Block(0 1 0) =   2 | Thread(3 1 0) =   7
# 0136 | Block(0 1 0) =   2 | Thread(0 2 0) =   8
# 0137 | Block(0 1 0) =   2 | Thread(1 2 0) =   9
# 0138 | Block(0 1 0) =   2 | Thread(2 2 0) =  10
# 0139 | Block(0 1 0) =   2 | Thread(3 2 0) =  11
# 0140 | Block(0 1 0) =   2 | Thread(0 3 0) =  12
# 0141 | Block(0 1 0) =   2 | Thread(1 3 0) =  13
# 0142 | Block(0 1 0) =   2 | Thread(2 3 0) =  14
# 0143 | Block(0 1 0) =   2 | Thread(3 3 0) =  15
# 0144 | Block(0 1 0) =   2 | Thread(0 0 1) =  16
# 0145 | Block(0 1 0) =   2 | Thread(1 0 1) =  17
# 0146 | Block(0 1 0) =   2 | Thread(2 0 1) =  18
# 0147 | Block(0 1 0) =   2 | Thread(3 0 1) =  19
# 0148 | Block(0 1 0) =   2 | Thread(0 1 1) =  20
# 0149 | Block(0 1 0) =   2 | Thread(1 1 1) =  21
# 0150 | Block(0 1 0) =   2 | Thread(2 1 1) =  22
# 0151 | Block(0 1 0) =   2 | Thread(3 1 1) =  23
# 0152 | Block(0 1 0) =   2 | Thread(0 2 1) =  24
# 0153 | Block(0 1 0) =   2 | Thread(1 2 1) =  25
# 0154 | Block(0 1 0) =   2 | Thread(2 2 1) =  26
# 0155 | Block(0 1 0) =   2 | Thread(3 2 1) =  27
# 0156 | Block(0 1 0) =   2 | Thread(0 3 1) =  28
# 0157 | Block(0 1 0) =   2 | Thread(1 3 1) =  29
# 0158 | Block(0 1 0) =   2 | Thread(2 3 1) =  30
# 0159 | Block(0 1 0) =   2 | Thread(3 3 1) =  31
# 1408 | Block(0 2 3) =  22 | Thread(0 0 0) =   0
# 1409 | Block(0 2 3) =  22 | Thread(1 0 0) =   1
# 1410 | Block(0 2 3) =  22 | Thread(2 0 0) =   2
# 1411 | Block(0 2 3) =  22 | Thread(3 0 0) =   3
# 1412 | Block(0 2 3) =  22 | Thread(0 1 0) =   4
# 1413 | Block(0 2 3) =  22 | Thread(1 1 0) =   5
# 1414 | Block(0 2 3) =  22 | Thread(2 1 0) =   6
# 1415 | Block(0 2 3) =  22 | Thread(3 1 0) =   7
# 1416 | Block(0 2 3) =  22 | Thread(0 2 0) =   8
# 1417 | Block(0 2 3) =  22 | Thread(1 2 0) =   9
# 1418 | Block(0 2 3) =  22 | Thread(2 2 0) =  10
# 1419 | Block(0 2 3) =  22 | Thread(3 2 0) =  11
# 1420 | Block(0 2 3) =  22 | Thread(0 3 0) =  12
# 1421 | Block(0 2 3) =  22 | Thread(1 3 0) =  13
# 1422 | Block(0 2 3) =  22 | Thread(2 3 0) =  14
# 1423 | Block(0 2 3) =  22 | Thread(3 3 0) =  15
# 1424 | Block(0 2 3) =  22 | Thread(0 0 1) =  16
# 1425 | Block(0 2 3) =  22 | Thread(1 0 1) =  17
# 1426 | Block(0 2 3) =  22 | Thread(2 0 1) =  18
# 1427 | Block(0 2 3) =  22 | Thread(3 0 1) =  19
# 1428 | Block(0 2 3) =  22 | Thread(0 1 1) =  20
# 1429 | Block(0 2 3) =  22 | Thread(1 1 1) =  21
# 1430 | Block(0 2 3) =  22 | Thread(2 1 1) =  22
# 1431 | Block(0 2 3) =  22 | Thread(3 1 1) =  23
# 1432 | Block(0 2 3) =  22 | Thread(0 2 1) =  24
# 1433 | Block(0 2 3) =  22 | Thread(1 2 1) =  25
# 1434 | Block(0 2 3) =  22 | Thread(2 2 1) =  26
# 1435 | Block(0 2 3) =  22 | Thread(3 2 1) =  27
# 1436 | Block(0 2 3) =  22 | Thread(0 3 1) =  28
# 1437 | Block(0 2 3) =  22 | Thread(1 3 1) =  29
# 1438 | Block(0 2 3) =  22 | Thread(2 3 1) =  30
# 1439 | Block(0 2 3) =  22 | Thread(3 3 1) =  31
# 0160 | Block(0 1 0) =   2 | Thread(0 0 2) =  32
# 0161 | Block(0 1 0) =   2 | Thread(1 0 2) =  33
# 0162 | Block(0 1 0) =   2 | Thread(2 0 2) =  34
# 0163 | Block(0 1 0) =   2 | Thread(3 0 2) =  35
# 0164 | Block(0 1 0) =   2 | Thread(0 1 2) =  36
# 0165 | Block(0 1 0) =   2 | Thread(1 1 2) =  37
# 0166 | Block(0 1 0) =   2 | Thread(2 1 2) =  38
# 0167 | Block(0 1 0) =   2 | Thread(3 1 2) =  39
# 0168 | Block(0 1 0) =   2 | Thread(0 2 2) =  40
# 0169 | Block(0 1 0) =   2 | Thread(1 2 2) =  41
# 0170 | Block(0 1 0) =   2 | Thread(2 2 2) =  42
# 0171 | Block(0 1 0) =   2 | Thread(3 2 2) =  43
# 0172 | Block(0 1 0) =   2 | Thread(0 3 2) =  44
# 0173 | Block(0 1 0) =   2 | Thread(1 3 2) =  45
# 0174 | Block(0 1 0) =   2 | Thread(2 3 2) =  46
# 0175 | Block(0 1 0) =   2 | Thread(3 3 2) =  47
# 0176 | Block(0 1 0) =   2 | Thread(0 0 3) =  48
# 0177 | Block(0 1 0) =   2 | Thread(1 0 3) =  49
# 0178 | Block(0 1 0) =   2 | Thread(2 0 3) =  50
# 0179 | Block(0 1 0) =   2 | Thread(3 0 3) =  51
# 0180 | Block(0 1 0) =   2 | Thread(0 1 3) =  52
# 0181 | Block(0 1 0) =   2 | Thread(1 1 3) =  53
# 0182 | Block(0 1 0) =   2 | Thread(2 1 3) =  54
# 0183 | Block(0 1 0) =   2 | Thread(3 1 3) =  55
# 0184 | Block(0 1 0) =   2 | Thread(0 2 3) =  56
# 0185 | Block(0 1 0) =   2 | Thread(1 2 3) =  57
# 0186 | Block(0 1 0) =   2 | Thread(2 2 3) =  58
# 0187 | Block(0 1 0) =   2 | Thread(3 2 3) =  59
# 0188 | Block(0 1 0) =   2 | Thread(0 3 3) =  60
# 0189 | Block(0 1 0) =   2 | Thread(1 3 3) =  61
# 0190 | Block(0 1 0) =   2 | Thread(2 3 3) =  62
# 0191 | Block(0 1 0) =   2 | Thread(3 3 3) =  63
# 1440 | Block(0 2 3) =  22 | Thread(0 0 2) =  32
# 1441 | Block(0 2 3) =  22 | Thread(1 0 2) =  33
# 1442 | Block(0 2 3) =  22 | Thread(2 0 2) =  34
# 1443 | Block(0 2 3) =  22 | Thread(3 0 2) =  35
# 1444 | Block(0 2 3) =  22 | Thread(0 1 2) =  36
# 1445 | Block(0 2 3) =  22 | Thread(1 1 2) =  37
# 1446 | Block(0 2 3) =  22 | Thread(2 1 2) =  38
# 1447 | Block(0 2 3) =  22 | Thread(3 1 2) =  39
# 1448 | Block(0 2 3) =  22 | Thread(0 2 2) =  40
# 1449 | Block(0 2 3) =  22 | Thread(1 2 2) =  41
# 1450 | Block(0 2 3) =  22 | Thread(2 2 2) =  42
# 1451 | Block(0 2 3) =  22 | Thread(3 2 2) =  43
# 1452 | Block(0 2 3) =  22 | Thread(0 3 2) =  44
# 1453 | Block(0 2 3) =  22 | Thread(1 3 2) =  45
# 1454 | Block(0 2 3) =  22 | Thread(2 3 2) =  46
# 1455 | Block(0 2 3) =  22 | Thread(3 3 2) =  47
# 1456 | Block(0 2 3) =  22 | Thread(0 0 3) =  48
# 1457 | Block(0 2 3) =  22 | Thread(1 0 3) =  49
# 1458 | Block(0 2 3) =  22 | Thread(2 0 3) =  50
# 1459 | Block(0 2 3) =  22 | Thread(3 0 3) =  51
# 1460 | Block(0 2 3) =  22 | Thread(0 1 3) =  52
# 1461 | Block(0 2 3) =  22 | Thread(1 1 3) =  53
# 1462 | Block(0 2 3) =  22 | Thread(2 1 3) =  54
# 1463 | Block(0 2 3) =  22 | Thread(3 1 3) =  55
# 1464 | Block(0 2 3) =  22 | Thread(0 2 3) =  56
# 1465 | Block(0 2 3) =  22 | Thread(1 2 3) =  57
# 1466 | Block(0 2 3) =  22 | Thread(2 2 3) =  58
# 1467 | Block(0 2 3) =  22 | Thread(3 2 3) =  59
# 1468 | Block(0 2 3) =  22 | Thread(0 3 3) =  60
# 1469 | Block(0 2 3) =  22 | Thread(1 3 3) =  61
# 1470 | Block(0 2 3) =  22 | Thread(2 3 3) =  62
# 1471 | Block(0 2 3) =  22 | Thread(3 3 3) =  63
# 1024 | Block(0 2 2) =  16 | Thread(0 0 0) =   0
# 1025 | Block(0 2 2) =  16 | Thread(1 0 0) =   1
# 1026 | Block(0 2 2) =  16 | Thread(2 0 0) =   2
# 1027 | Block(0 2 2) =  16 | Thread(3 0 0) =   3
# 1028 | Block(0 2 2) =  16 | Thread(0 1 0) =   4
# 1029 | Block(0 2 2) =  16 | Thread(1 1 0) =   5
# 1030 | Block(0 2 2) =  16 | Thread(2 1 0) =   6
# 1031 | Block(0 2 2) =  16 | Thread(3 1 0) =   7
# 1032 | Block(0 2 2) =  16 | Thread(0 2 0) =   8
# 1033 | Block(0 2 2) =  16 | Thread(1 2 0) =   9
# 1034 | Block(0 2 2) =  16 | Thread(2 2 0) =  10
# 1035 | Block(0 2 2) =  16 | Thread(3 2 0) =  11
# 1036 | Block(0 2 2) =  16 | Thread(0 3 0) =  12
# 1037 | Block(0 2 2) =  16 | Thread(1 3 0) =  13
# 1038 | Block(0 2 2) =  16 | Thread(2 3 0) =  14
# 1039 | Block(0 2 2) =  16 | Thread(3 3 0) =  15
# 1040 | Block(0 2 2) =  16 | Thread(0 0 1) =  16
# 1041 | Block(0 2 2) =  16 | Thread(1 0 1) =  17
# 1042 | Block(0 2 2) =  16 | Thread(2 0 1) =  18
# 1043 | Block(0 2 2) =  16 | Thread(3 0 1) =  19
# 1044 | Block(0 2 2) =  16 | Thread(0 1 1) =  20
# 1045 | Block(0 2 2) =  16 | Thread(1 1 1) =  21
# 1046 | Block(0 2 2) =  16 | Thread(2 1 1) =  22
# 1047 | Block(0 2 2) =  16 | Thread(3 1 1) =  23
# 1048 | Block(0 2 2) =  16 | Thread(0 2 1) =  24
# 1049 | Block(0 2 2) =  16 | Thread(1 2 1) =  25
# 1050 | Block(0 2 2) =  16 | Thread(2 2 1) =  26
# 1051 | Block(0 2 2) =  16 | Thread(3 2 1) =  27
# 1052 | Block(0 2 2) =  16 | Thread(0 3 1) =  28
# 1053 | Block(0 2 2) =  16 | Thread(1 3 1) =  29
# 1054 | Block(0 2 2) =  16 | Thread(2 3 1) =  30
# 1055 | Block(0 2 2) =  16 | Thread(3 3 1) =  31
# 1056 | Block(0 2 2) =  16 | Thread(0 0 2) =  32
# 1057 | Block(0 2 2) =  16 | Thread(1 0 2) =  33
# 1058 | Block(0 2 2) =  16 | Thread(2 0 2) =  34
# 1059 | Block(0 2 2) =  16 | Thread(3 0 2) =  35
# 1060 | Block(0 2 2) =  16 | Thread(0 1 2) =  36
# 1061 | Block(0 2 2) =  16 | Thread(1 1 2) =  37
# 1062 | Block(0 2 2) =  16 | Thread(2 1 2) =  38
# 1063 | Block(0 2 2) =  16 | Thread(3 1 2) =  39
# 1064 | Block(0 2 2) =  16 | Thread(0 2 2) =  40
# 1065 | Block(0 2 2) =  16 | Thread(1 2 2) =  41
# 1066 | Block(0 2 2) =  16 | Thread(2 2 2) =  42
# 1067 | Block(0 2 2) =  16 | Thread(3 2 2) =  43
# 1068 | Block(0 2 2) =  16 | Thread(0 3 2) =  44
# 1069 | Block(0 2 2) =  16 | Thread(1 3 2) =  45
# 1070 | Block(0 2 2) =  16 | Thread(2 3 2) =  46
# 1071 | Block(0 2 2) =  16 | Thread(3 3 2) =  47
# 1072 | Block(0 2 2) =  16 | Thread(0 0 3) =  48
# 1073 | Block(0 2 2) =  16 | Thread(1 0 3) =  49
# 1074 | Block(0 2 2) =  16 | Thread(2 0 3) =  50
# 1075 | Block(0 2 2) =  16 | Thread(3 0 3) =  51
# 1076 | Block(0 2 2) =  16 | Thread(0 1 3) =  52
# 1077 | Block(0 2 2) =  16 | Thread(1 1 3) =  53
# 1078 | Block(0 2 2) =  16 | Thread(2 1 3) =  54
# 1079 | Block(0 2 2) =  16 | Thread(3 1 3) =  55
# 1080 | Block(0 2 2) =  16 | Thread(0 2 3) =  56
# 1081 | Block(0 2 2) =  16 | Thread(1 2 3) =  57
# 1082 | Block(0 2 2) =  16 | Thread(2 2 3) =  58
# 1083 | Block(0 2 2) =  16 | Thread(3 2 3) =  59
# 1084 | Block(0 2 2) =  16 | Thread(0 3 3) =  60
# 1085 | Block(0 2 2) =  16 | Thread(1 3 3) =  61
# 1086 | Block(0 2 2) =  16 | Thread(2 3 3) =  62
# 1087 | Block(0 2 2) =  16 | Thread(3 3 3) =  63
# 0512 | Block(0 1 1) =   8 | Thread(0 0 0) =   0
# 0513 | Block(0 1 1) =   8 | Thread(1 0 0) =   1
# 0514 | Block(0 1 1) =   8 | Thread(2 0 0) =   2
# 0515 | Block(0 1 1) =   8 | Thread(3 0 0) =   3
# 0516 | Block(0 1 1) =   8 | Thread(0 1 0) =   4
# 0517 | Block(0 1 1) =   8 | Thread(1 1 0) =   5
# 0518 | Block(0 1 1) =   8 | Thread(2 1 0) =   6
# 0519 | Block(0 1 1) =   8 | Thread(3 1 0) =   7
# 0520 | Block(0 1 1) =   8 | Thread(0 2 0) =   8
# 0521 | Block(0 1 1) =   8 | Thread(1 2 0) =   9
# 0522 | Block(0 1 1) =   8 | Thread(2 2 0) =  10
# 0523 | Block(0 1 1) =   8 | Thread(3 2 0) =  11
# 0524 | Block(0 1 1) =   8 | Thread(0 3 0) =  12
# 0525 | Block(0 1 1) =   8 | Thread(1 3 0) =  13
# 0526 | Block(0 1 1) =   8 | Thread(2 3 0) =  14
# 0527 | Block(0 1 1) =   8 | Thread(3 3 0) =  15
# 0528 | Block(0 1 1) =   8 | Thread(0 0 1) =  16
# 0529 | Block(0 1 1) =   8 | Thread(1 0 1) =  17
# 0530 | Block(0 1 1) =   8 | Thread(2 0 1) =  18
# 0531 | Block(0 1 1) =   8 | Thread(3 0 1) =  19
# 0532 | Block(0 1 1) =   8 | Thread(0 1 1) =  20
# 0533 | Block(0 1 1) =   8 | Thread(1 1 1) =  21
# 0534 | Block(0 1 1) =   8 | Thread(2 1 1) =  22
# 0535 | Block(0 1 1) =   8 | Thread(3 1 1) =  23
# 0536 | Block(0 1 1) =   8 | Thread(0 2 1) =  24
# 0537 | Block(0 1 1) =   8 | Thread(1 2 1) =  25
# 0538 | Block(0 1 1) =   8 | Thread(2 2 1) =  26
# 0539 | Block(0 1 1) =   8 | Thread(3 2 1) =  27
# 0540 | Block(0 1 1) =   8 | Thread(0 3 1) =  28
# 0541 | Block(0 1 1) =   8 | Thread(1 3 1) =  29
# 0542 | Block(0 1 1) =   8 | Thread(2 3 1) =  30
# 0543 | Block(0 1 1) =   8 | Thread(3 3 1) =  31
# 0544 | Block(0 1 1) =   8 | Thread(0 0 2) =  32
# 0545 | Block(0 1 1) =   8 | Thread(1 0 2) =  33
# 0546 | Block(0 1 1) =   8 | Thread(2 0 2) =  34
# 0547 | Block(0 1 1) =   8 | Thread(3 0 2) =  35
# 0548 | Block(0 1 1) =   8 | Thread(0 1 2) =  36
# 0549 | Block(0 1 1) =   8 | Thread(1 1 2) =  37
# 0550 | Block(0 1 1) =   8 | Thread(2 1 2) =  38
# 0551 | Block(0 1 1) =   8 | Thread(3 1 2) =  39
# 0552 | Block(0 1 1) =   8 | Thread(0 2 2) =  40
# 0553 | Block(0 1 1) =   8 | Thread(1 2 2) =  41
# 0554 | Block(0 1 1) =   8 | Thread(2 2 2) =  42
# 0555 | Block(0 1 1) =   8 | Thread(3 2 2) =  43
# 0556 | Block(0 1 1) =   8 | Thread(0 3 2) =  44
# 0557 | Block(0 1 1) =   8 | Thread(1 3 2) =  45
# 0558 | Block(0 1 1) =   8 | Thread(2 3 2) =  46
# 0559 | Block(0 1 1) =   8 | Thread(3 3 2) =  47
# 0560 | Block(0 1 1) =   8 | Thread(0 0 3) =  48
# 0561 | Block(0 1 1) =   8 | Thread(1 0 3) =  49
# 0562 | Block(0 1 1) =   8 | Thread(2 0 3) =  50
# 0563 | Block(0 1 1) =   8 | Thread(3 0 3) =  51
# 0564 | Block(0 1 1) =   8 | Thread(0 1 3) =  52
# 0565 | Block(0 1 1) =   8 | Thread(1 1 3) =  53
# 0566 | Block(0 1 1) =   8 | Thread(2 1 3) =  54
# 0567 | Block(0 1 1) =   8 | Thread(3 1 3) =  55
# 0568 | Block(0 1 1) =   8 | Thread(0 2 3) =  56
# 0569 | Block(0 1 1) =   8 | Thread(1 2 3) =  57
# 0570 | Block(0 1 1) =   8 | Thread(2 2 3) =  58
# 0571 | Block(0 1 1) =   8 | Thread(3 2 3) =  59
# 0572 | Block(0 1 1) =   8 | Thread(0 3 3) =  60
# 0573 | Block(0 1 1) =   8 | Thread(1 3 3) =  61
# 0574 | Block(0 1 1) =   8 | Thread(2 3 3) =  62
# 0575 | Block(0 1 1) =   8 | Thread(3 3 3) =  63
# 0704 | Block(1 2 1) =  11 | Thread(0 0 0) =   0
# 0705 | Block(1 2 1) =  11 | Thread(1 0 0) =   1
# 0706 | Block(1 2 1) =  11 | Thread(2 0 0) =   2
# 0707 | Block(1 2 1) =  11 | Thread(3 0 0) =   3
# 0708 | Block(1 2 1) =  11 | Thread(0 1 0) =   4
# 0709 | Block(1 2 1) =  11 | Thread(1 1 0) =   5
# 0710 | Block(1 2 1) =  11 | Thread(2 1 0) =   6
# 0711 | Block(1 2 1) =  11 | Thread(3 1 0) =   7
# 0712 | Block(1 2 1) =  11 | Thread(0 2 0) =   8
# 0713 | Block(1 2 1) =  11 | Thread(1 2 0) =   9
# 0714 | Block(1 2 1) =  11 | Thread(2 2 0) =  10
# 0715 | Block(1 2 1) =  11 | Thread(3 2 0) =  11
# 0716 | Block(1 2 1) =  11 | Thread(0 3 0) =  12
# 0717 | Block(1 2 1) =  11 | Thread(1 3 0) =  13
# 0718 | Block(1 2 1) =  11 | Thread(2 3 0) =  14
# 0719 | Block(1 2 1) =  11 | Thread(3 3 0) =  15
# 0720 | Block(1 2 1) =  11 | Thread(0 0 1) =  16
# 0721 | Block(1 2 1) =  11 | Thread(1 0 1) =  17
# 0722 | Block(1 2 1) =  11 | Thread(2 0 1) =  18
# 0723 | Block(1 2 1) =  11 | Thread(3 0 1) =  19
# 0724 | Block(1 2 1) =  11 | Thread(0 1 1) =  20
# 0725 | Block(1 2 1) =  11 | Thread(1 1 1) =  21
# 0726 | Block(1 2 1) =  11 | Thread(2 1 1) =  22
# 0727 | Block(1 2 1) =  11 | Thread(3 1 1) =  23
# 0728 | Block(1 2 1) =  11 | Thread(0 2 1) =  24
# 0729 | Block(1 2 1) =  11 | Thread(1 2 1) =  25
# 0730 | Block(1 2 1) =  11 | Thread(2 2 1) =  26
# 0731 | Block(1 2 1) =  11 | Thread(3 2 1) =  27
# 0732 | Block(1 2 1) =  11 | Thread(0 3 1) =  28
# 0733 | Block(1 2 1) =  11 | Thread(1 3 1) =  29
# 0734 | Block(1 2 1) =  11 | Thread(2 3 1) =  30
# 0735 | Block(1 2 1) =  11 | Thread(3 3 1) =  31
# 0736 | Block(1 2 1) =  11 | Thread(0 0 2) =  32
# 0737 | Block(1 2 1) =  11 | Thread(1 0 2) =  33
# 0738 | Block(1 2 1) =  11 | Thread(2 0 2) =  34
# 0739 | Block(1 2 1) =  11 | Thread(3 0 2) =  35
# 0740 | Block(1 2 1) =  11 | Thread(0 1 2) =  36
# 0741 | Block(1 2 1) =  11 | Thread(1 1 2) =  37
# ...
# 0243 | Block(1 1 0) =   3 | Thread(3 0 3) =  51
# 0244 | Block(1 1 0) =   3 | Thread(0 1 3) =  52
# 0245 | Block(1 1 0) =   3 | Thread(1 1 3) =  53
# 0246 | Block(1 1 0) =   3 | Thread(2 1 3) =  54
# 0247 | Block(1 1 0) =   3 | Thread(3 1 3) =  55
# 0248 | Block(1 1 0) =   3 | Thread(0 2 3) =  56
# 0249 | Block(1 1 0) =   3 | Thread(1 2 3) =  57
# 0250 | Block(1 1 0) =   3 | Thread(2 2 3) =  58
# 0251 | Block(1 1 0) =   3 | Thread(3 2 3) =  59
# 0252 | Block(1 1 0) =   3 | Thread(0 3 3) =  60
# 0253 | Block(1 1 0) =   3 | Thread(1 3 3) =  61
# 0254 | Block(1 1 0) =   3 | Thread(2 3 3) =  62
# 0255 | Block(1 1 0) =   3 | Thread(3 3 3) =  63
# 1280 | Block(0 1 3) =  20 | Thread(0 0 0) =   0
# 1281 | Block(0 1 3) =  20 | Thread(1 0 0) =   1
# 1282 | Block(0 1 3) =  20 | Thread(2 0 0) =   2
# 1283 | Block(0 1 3) =  20 | Thread(3 0 0) =   3
# 1284 | Block(0 1 3) =  20 | Thread(0 1 0) =   4
# 1285 | Block(0 1 3) =  20 | Thread(1 1 0) =   5
# 1286 | Block(0 1 3) =  20 | Thread(2 1 0) =   6
# 1287 | Block(0 1 3) =  20 | Thread(3 1 0) =   7
# 1288 | Block(0 1 3) =  20 | Thread(0 2 0) =   8
# 1289 | Block(0 1 3) =  20 | Thread(1 2 0) =   9
# 1290 | Block(0 1 3) =  20 | Thread(2 2 0) =  10
# 1291 | Block(0 1 3) =  20 | Thread(3 2 0) =  11
# 1292 | Block(0 1 3) =  20 | Thread(0 3 0) =  12
# 1293 | Block(0 1 3) =  20 | Thread(1 3 0) =  13
# 1294 | Block(0 1 3) =  20 | Thread(2 3 0) =  14
# 1295 | Block(0 1 3) =  20 | Thread(3 3 0) =  15
# 1296 | Block(0 1 3) =  20 | Thread(0 0 1) =  16
# 1297 | Block(0 1 3) =  20 | Thread(1 0 1) =  17
# 1298 | Block(0 1 3) =  20 | Thread(2 0 1) =  18
# 1299 | Block(0 1 3) =  20 | Thread(3 0 1) =  19
# 1300 | Block(0 1 3) =  20 | Thread(0 1 1) =  20
# 1301 | Block(0 1 3) =  20 | Thread(1 1 1) =  21
# 1302 | Block(0 1 3) =  20 | Thread(2 1 1) =  22
# 1303 | Block(0 1 3) =  20 | Thread(3 1 1) =  23
# 1304 | Block(0 1 3) =  20 | Thread(0 2 1) =  24
# 1305 | Block(0 1 3) =  20 | Thread(1 2 1) =  25
# 1306 | Block(0 1 3) =  20 | Thread(2 2 1) =  26
# 1307 | Block(0 1 3) =  20 | Thread(3 2 1) =  27
# 1308 | Block(0 1 3) =  20 | Thread(0 3 1) =  28
# 1309 | Block(0 1 3) =  20 | Thread(1 3 1) =  29
# 1310 | Block(0 1 3) =  20 | Thread(2 3 1) =  30
# 1311 | Block(0 1 3) =  20 | Thread(3 3 1) =  31
# 1312 | Block(0 1 3) =  20 | Thread(0 0 2) =  32
# 1313 | Block(0 1 3) =  20 | Thread(1 0 2) =  33
# 1314 | Block(0 1 3) =  20 | Thread(2 0 2) =  34
# 1315 | Block(0 1 3) =  20 | Thread(3 0 2) =  35
# 1316 | Block(0 1 3) =  20 | Thread(0 1 2) =  36
# 1317 | Block(0 1 3) =  20 | Thread(1 1 2) =  37
# 1318 | Block(0 1 3) =  20 | Thread(2 1 2) =  38
# 1319 | Block(0 1 3) =  20 | Thread(3 1 2) =  39
# 1320 | Block(0 1 3) =  20 | Thread(0 2 2) =  40
# 1321 | Block(0 1 3) =  20 | Thread(1 2 2) =  41
# 1322 | Block(0 1 3) =  20 | Thread(2 2 2) =  42
# 1323 | Block(0 1 3) =  20 | Thread(3 2 2) =  43
# 1324 | Block(0 1 3) =  20 | Thread(0 3 2) =  44
# 1325 | Block(0 1 3) =  20 | Thread(1 3 2) =  45
# 1326 | Block(0 1 3) =  20 | Thread(2 3 2) =  46
# 1327 | Block(0 1 3) =  20 | Thread(3 3 2) =  47
# 1328 | Block(0 1 3) =  20 | Thread(0 0 3) =  48
# 1329 | Block(0 1 3) =  20 | Thread(1 0 3) =  49
# 1330 | Block(0 1 3) =  20 | Thread(2 0 3) =  50
# 1331 | Block(0 1 3) =  20 | Thread(3 0 3) =  51
# 1332 | Block(0 1 3) =  20 | Thread(0 1 3) =  52
# 1333 | Block(0 1 3) =  20 | Thread(1 1 3) =  53
# 1334 | Block(0 1 3) =  20 | Thread(2 1 3) =  54
# 1335 | Block(0 1 3) =  20 | Thread(3 1 3) =  55
# 1336 | Block(0 1 3) =  20 | Thread(0 2 3) =  56
# 1337 | Block(0 1 3) =  20 | Thread(1 2 3) =  57
# 1338 | Block(0 1 3) =  20 | Thread(2 2 3) =  58
# 1339 | Block(0 1 3) =  20 | Thread(3 2 3) =  59
# 1340 | Block(0 1 3) =  20 | Thread(0 3 3) =  60
# 1341 | Block(0 1 3) =  20 | Thread(1 3 3) =  61
# 1342 | Block(0 1 3) =  20 | Thread(2 3 3) =  62
# 1343 | Block(0 1 3) =  20 | Thread(3 3 3) =  63
# 0000 | Block(0 0 0) =   0 | Thread(0 0 0) =   0
# 0001 | Block(0 0 0) =   0 | Thread(1 0 0) =   1
# 0002 | Block(0 0 0) =   0 | Thread(2 0 0) =   2
# 0003 | Block(0 0 0) =   0 | Thread(3 0 0) =   3
# 0004 | Block(0 0 0) =   0 | Thread(0 1 0) =   4
# 0005 | Block(0 0 0) =   0 | Thread(1 1 0) =   5
# 0006 | Block(0 0 0) =   0 | Thread(2 1 0) =   6
# 0007 | Block(0 0 0) =   0 | Thread(3 1 0) =   7
# 0008 | Block(0 0 0) =   0 | Thread(0 2 0) =   8
# 0009 | Block(0 0 0) =   0 | Thread(1 2 0) =   9
# 0010 | Block(0 0 0) =   0 | Thread(2 2 0) =  10
# 0011 | Block(0 0 0) =   0 | Thread(3 2 0) =  11
# 0012 | Block(0 0 0) =   0 | Thread(0 3 0) =  12
# 0013 | Block(0 0 0) =   0 | Thread(1 3 0) =  13
# 0014 | Block(0 0 0) =   0 | Thread(2 3 0) =  14
# 0015 | Block(0 0 0) =   0 | Thread(3 3 0) =  15
# 0016 | Block(0 0 0) =   0 | Thread(0 0 1) =  16
# 0017 | Block(0 0 0) =   0 | Thread(1 0 1) =  17
# 0018 | Block(0 0 0) =   0 | Thread(2 0 1) =  18
# 0019 | Block(0 0 0) =   0 | Thread(3 0 1) =  19
# 0020 | Block(0 0 0) =   0 | Thread(0 1 1) =  20
# 0021 | Block(0 0 0) =   0 | Thread(1 1 1) =  21
# 0022 | Block(0 0 0) =   0 | Thread(2 1 1) =  22
# 0023 | Block(0 0 0) =   0 | Thread(3 1 1) =  23
# 0024 | Block(0 0 0) =   0 | Thread(0 2 1) =  24
# 0025 | Block(0 0 0) =   0 | Thread(1 2 1) =  25
# 0026 | Block(0 0 0) =   0 | Thread(2 2 1) =  26
# 0027 | Block(0 0 0) =   0 | Thread(3 2 1) =  27
# 0028 | Block(0 0 0) =   0 | Thread(0 3 1) =  28
# 0029 | Block(0 0 0) =   0 | Thread(1 3 1) =  29
# 0030 | Block(0 0 0) =   0 | Thread(2 3 1) =  30
# 0031 | Block(0 0 0) =   0 | Thread(3 3 1) =  31
# 0032 | Block(0 0 0) =   0 | Thread(0 0 2) =  32
# 0033 | Block(0 0 0) =   0 | Thread(1 0 2) =  33
# 0034 | Block(0 0 0) =   0 | Thread(2 0 2) =  34
# 0035 | Block(0 0 0) =   0 | Thread(3 0 2) =  35
# 0036 | Block(0 0 0) =   0 | Thread(0 1 2) =  36
# 0037 | Block(0 0 0) =   0 | Thread(1 1 2) =  37
# 0038 | Block(0 0 0) =   0 | Thread(2 1 2) =  38
# 0039 | Block(0 0 0) =   0 | Thread(3 1 2) =  39
# 0040 | Block(0 0 0) =   0 | Thread(0 2 2) =  40
# 0041 | Block(0 0 0) =   0 | Thread(1 2 2) =  41
# 0042 | Block(0 0 0) =   0 | Thread(2 2 2) =  42
# 0043 | Block(0 0 0) =   0 | Thread(3 2 2) =  43
# 0044 | Block(0 0 0) =   0 | Thread(0 3 2) =  44
# 0045 | Block(0 0 0) =   0 | Thread(1 3 2) =  45
# 0046 | Block(0 0 0) =   0 | Thread(2 3 2) =  46
# 0047 | Block(0 0 0) =   0 | Thread(3 3 2) =  47
# 0048 | Block(0 0 0) =   0 | Thread(0 0 3) =  48
# 0049 | Block(0 0 0) =   0 | Thread(1 0 3) =  49
# 0050 | Block(0 0 0) =   0 | Thread(2 0 3) =  50
# 0051 | Block(0 0 0) =   0 | Thread(3 0 3) =  51
# 0052 | Block(0 0 0) =   0 | Thread(0 1 3) =  52
# 0053 | Block(0 0 0) =   0 | Thread(1 1 3) =  53
# 0054 | Block(0 0 0) =   0 | Thread(2 1 3) =  54
# 0055 | Block(0 0 0) =   0 | Thread(3 1 3) =  55
# 0056 | Block(0 0 0) =   0 | Thread(0 2 3) =  56
# 0057 | Block(0 0 0) =   0 | Thread(1 2 3) =  57
# 0058 | Block(0 0 0) =   0 | Thread(2 2 3) =  58
# 0059 | Block(0 0 0) =   0 | Thread(3 2 3) =  59
# 0060 | Block(0 0 0) =   0 | Thread(0 3 3) =  60
# 0061 | Block(0 0 0) =   0 | Thread(1 3 3) =  61
# 0062 | Block(0 0 0) =   0 | Thread(2 3 3) =  62
# 0063 | Block(0 0 0) =   0 | Thread(3 3 3) =  63
# 0384 | Block(0 0 1) =   6 | Thread(0 0 0) =   0
# 0385 | Block(0 0 1) =   6 | Thread(1 0 0) =   1
# 0386 | Block(0 0 1) =   6 | Thread(2 0 0) =   2
# 0387 | Block(0 0 1) =   6 | Thread(3 0 0) =   3
# 0388 | Block(0 0 1) =   6 | Thread(0 1 0) =   4
# 0389 | Block(0 0 1) =   6 | Thread(1 1 0) =   5
# 0390 | Block(0 0 1) =   6 | Thread(2 1 0) =   6
# 0391 | Block(0 0 1) =   6 | Thread(3 1 0) =   7
# 0392 | Block(0 0 1) =   6 | Thread(0 2 0) =   8
# 0393 | Block(0 0 1) =   6 | Thread(1 2 0) =   9
# 0394 | Block(0 0 1) =   6 | Thread(2 2 0) =  10
# 0395 | Block(0 0 1) =   6 | Thread(3 2 0) =  11
# 0396 | Block(0 0 1) =   6 | Thread(0 3 0) =  12
# 0397 | Block(0 0 1) =   6 | Thread(1 3 0) =  13
# 0398 | Block(0 0 1) =   6 | Thread(2 3 0) =  14
# 0399 | Block(0 0 1) =   6 | Thread(3 3 0) =  15
# 0400 | Block(0 0 1) =   6 | Thread(0 0 1) =  16
# 0401 | Block(0 0 1) =   6 | Thread(1 0 1) =  17
# 0402 | Block(0 0 1) =   6 | Thread(2 0 1) =  18
# 0403 | Block(0 0 1) =   6 | Thread(3 0 1) =  19
# 0404 | Block(0 0 1) =   6 | Thread(0 1 1) =  20
# 0405 | Block(0 0 1) =   6 | Thread(1 1 1) =  21
# 0406 | Block(0 0 1) =   6 | Thread(2 1 1) =  22
# 0407 | Block(0 0 1) =   6 | Thread(3 1 1) =  23
# 0408 | Block(0 0 1) =   6 | Thread(0 2 1) =  24
# 0409 | Block(0 0 1) =   6 | Thread(1 2 1) =  25
# 0410 | Block(0 0 1) =   6 | Thread(2 2 1) =  26
# 0411 | Block(0 0 1) =   6 | Thread(3 2 1) =  27
# 0412 | Block(0 0 1) =   6 | Thread(0 3 1) =  28
# 0413 | Block(0 0 1) =   6 | Thread(1 3 1) =  29
# 0414 | Block(0 0 1) =   6 | Thread(2 3 1) =  30
# 0415 | Block(0 0 1) =   6 | Thread(3 3 1) =  31
# 0416 | Block(0 0 1) =   6 | Thread(0 0 2) =  32
# 0417 | Block(0 0 1) =   6 | Thread(1 0 2) =  33
# 0418 | Block(0 0 1) =   6 | Thread(2 0 2) =  34
# 0419 | Block(0 0 1) =   6 | Thread(3 0 2) =  35
# 0420 | Block(0 0 1) =   6 | Thread(0 1 2) =  36
# 0421 | Block(0 0 1) =   6 | Thread(1 1 2) =  37
# 0422 | Block(0 0 1) =   6 | Thread(2 1 2) =  38
# 0423 | Block(0 0 1) =   6 | Thread(3 1 2) =  39
# 0424 | Block(0 0 1) =   6 | Thread(0 2 2) =  40
# 0425 | Block(0 0 1) =   6 | Thread(1 2 2) =  41
# 0426 | Block(0 0 1) =   6 | Thread(2 2 2) =  42
# 0427 | Block(0 0 1) =   6 | Thread(3 2 2) =  43
# 0428 | Block(0 0 1) =   6 | Thread(0 3 2) =  44
# 0429 | Block(0 0 1) =   6 | Thread(1 3 2) =  45
# 0430 | Block(0 0 1) =   6 | Thread(2 3 2) =  46
# 0431 | Block(0 0 1) =   6 | Thread(3 3 2) =  47
# 0432 | Block(0 0 1) =   6 | Thread(0 0 3) =  48
# 0433 | Block(0 0 1) =   6 | Thread(1 0 3) =  49
# 0434 | Block(0 0 1) =   6 | Thread(2 0 3) =  50
# 0435 | Block(0 0 1) =   6 | Thread(3 0 3) =  51
# 0436 | Block(0 0 1) =   6 | Thread(0 1 3) =  52
# 0437 | Block(0 0 1) =   6 | Thread(1 1 3) =  53
# 0438 | Block(0 0 1) =   6 | Thread(2 1 3) =  54
# 0439 | Block(0 0 1) =   6 | Thread(3 1 3) =  55
# 0440 | Block(0 0 1) =   6 | Thread(0 2 3) =  56
# 0441 | Block(0 0 1) =   6 | Thread(1 2 3) =  57
# 0442 | Block(0 0 1) =   6 | Thread(2 2 3) =  58
# 0443 | Block(0 0 1) =   6 | Thread(3 2 3) =  59
# 0444 | Block(0 0 1) =   6 | Thread(0 3 3) =  60
# 0445 | Block(0 0 1) =   6 | Thread(1 3 3) =  61
# 0446 | Block(0 0 1) =   6 | Thread(2 3 3) =  62
# 0447 | Block(0 0 1) =   6 | Thread(3 3 3) =  63
# 1344 | Block(1 1 3) =  21 | Thread(0 0 0) =   0
# 1345 | Block(1 1 3) =  21 | Thread(1 0 0) =   1
# 1346 | Block(1 1 3) =  21 | Thread(2 0 0) =   2
# 1347 | Block(1 1 3) =  21 | Thread(3 0 0) =   3
# 1348 | Block(1 1 3) =  21 | Thread(0 1 0) =   4
# 1349 | Block(1 1 3) =  21 | Thread(1 1 0) =   5
# 1350 | Block(1 1 3) =  21 | Thread(2 1 0) =   6
# 1351 | Block(1 1 3) =  21 | Thread(3 1 0) =   7
# 1352 | Block(1 1 3) =  21 | Thread(0 2 0) =   8
# 1353 | Block(1 1 3) =  21 | Thread(1 2 0) =   9
# 1354 | Block(1 1 3) =  21 | Thread(2 2 0) =  10
# 1355 | Block(1 1 3) =  21 | Thread(3 2 0) =  11
# 1356 | Block(1 1 3) =  21 | Thread(0 3 0) =  12
# 1357 | Block(1 1 3) =  21 | Thread(1 3 0) =  13
# 1358 | Block(1 1 3) =  21 | Thread(2 3 0) =  14
# 1359 | Block(1 1 3) =  21 | Thread(3 3 0) =  15
# 1360 | Block(1 1 3) =  21 | Thread(0 0 1) =  16
# 1361 | Block(1 1 3) =  21 | Thread(1 0 1) =  17
# 1362 | Block(1 1 3) =  21 | Thread(2 0 1) =  18
# 1363 | Block(1 1 3) =  21 | Thread(3 0 1) =  19
# 1364 | Block(1 1 3) =  21 | Thread(0 1 1) =  20
# 1365 | Block(1 1 3) =  21 | Thread(1 1 1) =  21
# 1366 | Block(1 1 3) =  21 | Thread(2 1 1) =  22
# 1367 | Block(1 1 3) =  21 | Thread(3 1 1) =  23
# 1368 | Block(1 1 3) =  21 | Thread(0 2 1) =  24
# 1369 | Block(1 1 3) =  21 | Thread(1 2 1) =  25
# 1370 | Block(1 1 3) =  21 | Thread(2 2 1) =  26
# 1371 | Block(1 1 3) =  21 | Thread(3 2 1) =  27
# 1372 | Block(1 1 3) =  21 | Thread(0 3 1) =  28
# 1373 | Block(1 1 3) =  21 | Thread(1 3 1) =  29
# 1374 | Block(1 1 3) =  21 | Thread(2 3 1) =  30
# 1375 | Block(1 1 3) =  21 | Thread(3 3 1) =  31
# 1376 | Block(1 1 3) =  21 | Thread(0 0 2) =  32
# 1377 | Block(1 1 3) =  21 | Thread(1 0 2) =  33
# 1378 | Block(1 1 3) =  21 | Thread(2 0 2) =  34
# 1379 | Block(1 1 3) =  21 | Thread(3 0 2) =  35
# 1380 | Block(1 1 3) =  21 | Thread(0 1 2) =  36
# 1381 | Block(1 1 3) =  21 | Thread(1 1 2) =  37
# 1382 | Block(1 1 3) =  21 | Thread(2 1 2) =  38
# 1383 | Block(1 1 3) =  21 | Thread(3 1 2) =  39
# 1384 | Block(1 1 3) =  21 | Thread(0 2 2) =  40
# 1385 | Block(1 1 3) =  21 | Thread(1 2 2) =  41
# 1386 | Block(1 1 3) =  21 | Thread(2 2 2) =  42
# 1387 | Block(1 1 3) =  21 | Thread(3 2 2) =  43
# 1388 | Block(1 1 3) =  21 | Thread(0 3 2) =  44
# 1389 | Block(1 1 3) =  21 | Thread(1 3 2) =  45
# 1390 | Block(1 1 3) =  21 | Thread(2 3 2) =  46
# 1391 | Block(1 1 3) =  21 | Thread(3 3 2) =  47
# 1392 | Block(1 1 3) =  21 | Thread(0 0 3) =  48
# 1393 | Block(1 1 3) =  21 | Thread(1 0 3) =  49
# 1394 | Block(1 1 3) =  21 | Thread(2 0 3) =  50
# 1395 | Block(1 1 3) =  21 | Thread(3 0 3) =  51
# 1396 | Block(1 1 3) =  21 | Thread(0 1 3) =  52
# 1397 | Block(1 1 3) =  21 | Thread(1 1 3) =  53
# 1398 | Block(1 1 3) =  21 | Thread(2 1 3) =  54
# 1399 | Block(1 1 3) =  21 | Thread(3 1 3) =  55
# 1400 | Block(1 1 3) =  21 | Thread(0 2 3) =  56
# 1401 | Block(1 1 3) =  21 | Thread(1 2 3) =  57
# 1402 | Block(1 1 3) =  21 | Thread(2 2 3) =  58
# 1403 | Block(1 1 3) =  21 | Thread(3 2 3) =  59
# 1404 | Block(1 1 3) =  21 | Thread(0 3 3) =  60
# 1405 | Block(1 1 3) =  21 | Thread(1 3 3) =  61
# 1406 | Block(1 1 3) =  21 | Thread(2 3 3) =  62
# 1407 | Block(1 1 3) =  21 | Thread(3 3 3) =  63
# 0064 | Block(1 0 0) =   1 | Thread(0 0 0) =   0
# 0065 | Block(1 0 0) =   1 | Thread(1 0 0) =   1
# 0066 | Block(1 0 0) =   1 | Thread(2 0 0) =   2
# 0067 | Block(1 0 0) =   1 | Thread(3 0 0) =   3
# 0068 | Block(1 0 0) =   1 | Thread(0 1 0) =   4
# 0069 | Block(1 0 0) =   1 | Thread(1 1 0) =   5
# 0070 | Block(1 0 0) =   1 | Thread(2 1 0) =   6
# 0071 | Block(1 0 0) =   1 | Thread(3 1 0) =   7
# 0072 | Block(1 0 0) =   1 | Thread(0 2 0) =   8
# 0073 | Block(1 0 0) =   1 | Thread(1 2 0) =   9
# 0074 | Block(1 0 0) =   1 | Thread(2 2 0) =  10
# 0075 | Block(1 0 0) =   1 | Thread(3 2 0) =  11
# 0076 | Block(1 0 0) =   1 | Thread(0 3 0) =  12
# 0077 | Block(1 0 0) =   1 | Thread(1 3 0) =  13
# 0078 | Block(1 0 0) =   1 | Thread(2 3 0) =  14
# 0079 | Block(1 0 0) =   1 | Thread(3 3 0) =  15
# 0080 | Block(1 0 0) =   1 | Thread(0 0 1) =  16
# 0081 | Block(1 0 0) =   1 | Thread(1 0 1) =  17
# 0082 | Block(1 0 0) =   1 | Thread(2 0 1) =  18
# 0083 | Block(1 0 0) =   1 | Thread(3 0 1) =  19
# 0084 | Block(1 0 0) =   1 | Thread(0 1 1) =  20
# 0085 | Block(1 0 0) =   1 | Thread(1 1 1) =  21
# 0086 | Block(1 0 0) =   1 | Thread(2 1 1) =  22
# 0087 | Block(1 0 0) =   1 | Thread(3 1 1) =  23
# 0088 | Block(1 0 0) =   1 | Thread(0 2 1) =  24
# 0089 | Block(1 0 0) =   1 | Thread(1 2 1) =  25
# 0090 | Block(1 0 0) =   1 | Thread(2 2 1) =  26
# 0091 | Block(1 0 0) =   1 | Thread(3 2 1) =  27
# 0092 | Block(1 0 0) =   1 | Thread(0 3 1) =  28
# 0093 | Block(1 0 0) =   1 | Thread(1 3 1) =  29
# 0094 | Block(1 0 0) =   1 | Thread(2 3 1) =  30
# 0095 | Block(1 0 0) =   1 | Thread(3 3 1) =  31
# 0096 | Block(1 0 0) =   1 | Thread(0 0 2) =  32
# 0097 | Block(1 0 0) =   1 | Thread(1 0 2) =  33
# 0098 | Block(1 0 0) =   1 | Thread(2 0 2) =  34
# 0099 | Block(1 0 0) =   1 | Thread(3 0 2) =  35
# 0100 | Block(1 0 0) =   1 | Thread(0 1 2) =  36
# 0101 | Block(1 0 0) =   1 | Thread(1 1 2) =  37
# 0102 | Block(1 0 0) =   1 | Thread(2 1 2) =  38
# 0103 | Block(1 0 0) =   1 | Thread(3 1 2) =  39
# 0104 | Block(1 0 0) =   1 | Thread(0 2 2) =  40
# 0105 | Block(1 0 0) =   1 | Thread(1 2 2) =  41
# 0106 | Block(1 0 0) =   1 | Thread(2 2 2) =  42
# 0107 | Block(1 0 0) =   1 | Thread(3 2 2) =  43
# 0108 | Block(1 0 0) =   1 | Thread(0 3 2) =  44
# 0109 | Block(1 0 0) =   1 | Thread(1 3 2) =  45
# 0110 | Block(1 0 0) =   1 | Thread(2 3 2) =  46
# 0111 | Block(1 0 0) =   1 | Thread(3 3 2) =  47
# 0112 | Block(1 0 0) =   1 | Thread(0 0 3) =  48
# 0113 | Block(1 0 0) =   1 | Thread(1 0 3) =  49
# 0114 | Block(1 0 0) =   1 | Thread(2 0 3) =  50
# 0115 | Block(1 0 0) =   1 | Thread(3 0 3) =  51
# 0116 | Block(1 0 0) =   1 | Thread(0 1 3) =  52
# 0117 | Block(1 0 0) =   1 | Thread(1 1 3) =  53
# 0118 | Block(1 0 0) =   1 | Thread(2 1 3) =  54
# 0119 | Block(1 0 0) =   1 | Thread(3 1 3) =  55
# 0120 | Block(1 0 0) =   1 | Thread(0 2 3) =  56
# 0121 | Block(1 0 0) =   1 | Thread(1 2 3) =  57
# 0122 | Block(1 0 0) =   1 | Thread(2 2 3) =  58
# 0123 | Block(1 0 0) =   1 | Thread(3 2 3) =  59
# 0124 | Block(1 0 0) =   1 | Thread(0 3 3) =  60
# 0125 | Block(1 0 0) =   1 | Thread(1 3 3) =  61
# 0126 | Block(1 0 0) =   1 | Thread(2 3 3) =  62
# 0127 | Block(1 0 0) =   1 | Thread(3 3 3) =  63
